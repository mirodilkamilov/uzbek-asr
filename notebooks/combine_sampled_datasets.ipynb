# %% [markdown]
# # Combined Sampled Uzbek Speech Datasets — Preparation Summary
#
# This notebook prepares the **case-sensitive Uzbek ASR training datasets** used for Whisper fine-tuning by:
#
# - Computing alignment metrics (**WER, CER, sequence similarity**) with light normalization
# - Fixing formatting inconsistencies (quotes, numbers, casing, duplicates)
# - Forcing perfect alignment where transcription differences are purely formatting-related
# - Splitting processing into **Stage 1 (baseline filtering)** and **Stage 2 (stricter filtering + augmentation)**
# - Merging all datasets into unified **combined case-sensitive CSVs** for training
#
# ---
#
# ## Datasets Available
#
# ![Datasets available](../resources/available_datasets.png)
#
# ## Datasets Included
#
# ### Stage 1 Summary
#
# - **≥ 5,743 speakers**
# - **245.02 total hours** (90.6% training)
# - **Read speech:** 152.16 h (68.5%)
# - **Conversational speech:** 69.91 h (31.5%)
# - **No augmentation applied**
#
# ### Stage 2 Summary
#
# - **≥ 4,170 speakers**
# - **161.00 total hours** (86.0% training)
# - **Read speech:** 78.74 h (56.9%)
# - **Conversational speech:** 59.77 h (43.1%)
# - **Augmented training audio:** 27.16 h (**19.6%** of training)
#
# ![Results](../resources/results.png)

# %%
import pandas as pd

import scripts.similarity_metrics as similarity_metrics
from scripts.similarity_metrics import NormalizationLevel

# %%
def apply_similarity_metrics(data_df: pd.DataFrame):
    df = data_df.copy()
    df.drop(columns=["ref_normalized", "hyp_normalized", "wer", "cer", "sequence_similarity", "ref_word_count",
                     "hyp_word_count"], inplace=True, errors="ignore")
    df.rename(columns={"predicted_sentence": "text_spt"}, inplace=True, errors="ignore")

    # Apply similarity metrics to each row
    metrics = df.apply(
        lambda row: similarity_metrics.calculate(
            reference=row["text_original"],
            hypothesis=row["text_spt"],
            normalization_level=NormalizationLevel.LIGHT),
        axis=1
    )

    # Convert list of dicts → DataFrame
    metrics_df = pd.DataFrame(metrics.tolist())

    metrics_df.index = df.index

    # Merge metric columns back into main DataFrame and save
    df = pd.concat([df, metrics_df], axis=1).sort_values("wer", ascending=False)
    return df

# %%
usc_df = pd.read_csv("uzbek-speech-corpus__case_insensitive.csv", index_col="id")
usc_df = apply_similarity_metrics(usc_df)
usc_df.to_csv("uzbek-speech-corpus__case_insensitive.csv", index_label="id")
usc_df
# Out:
#        speaker_id                      path  duration  word_count        type  \
# id
# 10093   911079671   911079671_1_16664_3.wav    3.9000           6  validation
# 1326    600717944     600717944_1_944_1.wav    3.1465           3       train
# 1325    600717944     600717944_1_943_1.wav    3.0265           3       train
# 1063    833428527    833428527_1_8207_2.wav    3.1465           3       train
# 2266           31         31_data_31-47.wav    3.7200           2       train
# ...           ...                       ...       ...         ...         ...
# 2228    307064776   307064776_1_74892_1.wav    3.4400           6       train
# 2418           33         33_data_33-79.wav    5.8000           8        test
# 16845   560947882   560947882_1_42542_1.wav    3.4465           4       train
# 16864  1187023182  1187023182_2_38747_1.wav    7.0145          11       train
# 6031    865108248   865108248_1_27733_1.wav    6.8665          11        test
#
#                                            text_original  \
# id
# 10093              birdan ikki yaxshi ikkidan uch yaxshi
# 1326                                men o'ttiz yoshdaman
# 1325                               men yigirma yoshdaman
# 1063                          bo'pti qoravoylar popuklar
# 2266                                    qaysi qo'rg'onga
# ...                                                  ...
# 2228            baland bo'yli o'zidan nur taratib turgan
# 2418   eng pastda chang chalayotgan go'zal bir qiznin...
# 16845                  faqat ikkalamiz yashaydigan joyga
# 16864  xo'jayin savdo ahliga xos tavozelik bilan so'r...
# 6031   tashqi iqtisodiy aloqalar va aksiyadorlar bila...
#
#                                                 text_spt  \
# id
# 10093                    1 dan 2 yaxshi, 2 dan 3 yaxshi.
# 1326                                   Men 30 yoshdaman.
# 1325                                   Men 20 yoshdaman.
# 1063                       Bo'pti, qoravoylar, popuklar.
# 2266                                   Qaysi qo'rg'onga?
# ...                                                  ...
# 2228            baland bo'yli o'zidan nur taratib turgan
# 2418   eng pastda chang chalayotgan go'zal bir qiznin...
# 16845                  faqat ikkalamiz yashaydigan joyga
# 16864  xo'jayin savdo ahliga xos tavozelik bilan so'r...
# 6031   tashqi iqtisodiy aloqalar va aksiyadorlar bila...
#
#                                           ref_normalized  \
# id
# 10093              birdan ikki yaxshi ikkidan uch yaxshi
# 1326                                men o'ttiz yoshdaman
# 1325                               men yigirma yoshdaman
# 1063                          bo'pti qoravoylar popuklar
# 2266                                    qaysi qo'rg'onga
# ...                                                  ...
# 2228            baland bo'yli o'zidan nur taratib turgan
# 2418   eng pastda chang chalayotgan go'zal bir qiznin...
# 16845                  faqat ikkalamiz yashaydigan joyga
# 16864  xo'jayin savdo ahliga xos tavozelik bilan so'r...
# 6031   tashqi iqtisodiy aloqalar va aksiyadorlar bila...
#
#                                           hyp_normalized     wer     cer  \
# id
# 10093                    1 dan 2 yaxshi, 2 dan 3 yaxshi.  1.3333  0.4324
# 1326                                   Men 30 yoshdaman.  1.0000  0.4000
# 1325                                   Men 20 yoshdaman.  1.0000  0.4286
# 1063                       Bo'pti, qoravoylar, popuklar.  1.0000  0.1538
# 2266                                   Qaysi qo'rg'onga?  1.0000  0.1250
# ...                                                  ...     ...     ...
# 2228            baland bo'yli o'zidan nur taratib turgan  0.0000  0.0000
# 2418   eng pastda chang chalayotgan go'zal bir qiznin...  0.0000  0.0000
# 16845                  faqat ikkalamiz yashaydigan joyga  0.0000  0.0000
# 16864  xo'jayin savdo ahliga xos tavozelik bilan so'r...  0.0000  0.0000
# 6031   tashqi iqtisodiy aloqalar va aksiyadorlar bila...  0.0000  0.0000
#
#        sequence_similarity  ref_word_count  hyp_word_count
# id
# 10093               0.6765               6               8
# 1326                0.7027               3               3
# 1325                0.6842               3               3
# 1063                0.9091               3               3
# 2266                0.9091               2               2
# ...                    ...             ...             ...
# 2228                1.0000               6               6
# 2418                1.0000               8               8
# 16845               1.0000               4               4
# 16864               1.0000              11              11
# 6031                1.0000              11              11
#
# [6113 rows x 14 columns]

# %%
feruza_speech_df = pd.read_csv("feruza_speech_part1.csv", index_col="id")
feruza_speech_df.drop(columns=["text_cyrillic"], inplace=True)
feruza_speech_df.rename(columns={"text_latin": "text_original"}, inplace=True)

# Reorder text_original column to be one before the last column
cols = list(feruza_speech_df.columns)
cols.remove("text_original")
cols.insert(3, "text_original")
feruza_speech_df = feruza_speech_df[cols]

feruza_speech_df = apply_similarity_metrics(feruza_speech_df)
feruza_speech_df
# Out:
#              path        type   duration  \
# id
# 1997   029-92.wav  validation   5.500063
# 1193  1055-86.wav       train   4.132000
# 1880   026-01.wav  validation   3.380000
# 369   1059-77.wav       train   5.367563
# 1967  029-105.wav  validation  18.548500
# ...           ...         ...        ...
# 621   1029-90.wav       train  15.860062
# 622   1053-10.wav       train  14.434750
# 703   1064-77.wav       train  12.057375
# 704   1011-34.wav       train  12.490000
# 626   1055-40.wav       train  11.111937
#
#                                           text_original  \
# id
# 1997                                      CH..., 1-may.
# 1193                               So'nggi tafsilotlar.
# 1880                                     B..., 19-mart.
# 369                                  Aloqador mavzular:
# 1967  — Unda o'n to'qqiz, mayli, o'n sakkiz ham bo'l...
# ...                                                 ...
# 621   AQSH parchalanadimi? - Sobiq prezident Donald ...
# 622   Islomda payg'ambarning har qanday tasviri, hat...
# 703   Hukumatning Istanbul bo'yicha natijalarni qayt...
# 704   Asli buxorolik Anvarov soxta pasport bilan Mar...
# 626   Rossiya Federatsiyasi Kengashi Prezident Putin...
#
#                                                text_spt  word_count  \
# id
# 1997                                           Ch 1-may           3
# 1193                                so'nggi tafsilotlar           2
# 1880                                          B 19-mart           3
# 369                                   aloqador mavzular           2
# 1967  Unda 19, mayli 18 ham bo'lsin. Indamaysan-a, k...          22
# ...                                                 ...         ...
# 621   AQSH parchalanadimi? Sobiq prezident Donald Tr...          19
# 622   Islomda payg'ambarning har qanday tasviri, hat...          16
# 703   Hukumatning Istanbul bo'yicha natijalarni qayt...          11
# 704   Asli buxorolik Anvarov soxta pasport bilan Mar...          14
# 626   Rossiya Federatsiyasi Kengashi Prezident Putin...          12
#
#                                          ref_normalized  \
# id
# 1997                                      CH..., 1-may.
# 1193                               So'nggi tafsilotlar.
# 1880                                     B..., 19-mart.
# 369                                  Aloqador mavzular:
# 1967  Unda o'n to'qqiz, mayli, o'n sakkiz ham bo'lsi...
# ...                                                 ...
# 621   AQSH parchalanadimi? Sobiq prezident Donald Tr...
# 622   Islomda payg'ambarning har qanday tasviri, hat...
# 703   Hukumatning Istanbul bo'yicha natijalarni qayt...
# 704   Asli buxorolik Anvarov soxta pasport bilan Mar...
# 626   Rossiya Federatsiyasi Kengashi Prezident Putin...
#
#                                          hyp_normalized     wer     cer  \
# id
# 1997                                           Ch 1-may  1.0000  0.4615
# 1193                                so'nggi tafsilotlar  1.0000  0.1000
# 1880                                          B 19-mart  1.0000  0.3571
# 369                                   aloqador mavzular  1.0000  0.1111
# 1967  Unda 19, mayli 18 ham bo'lsin. Indamaysan-a, k...  0.5714  0.2264
# ...                                                 ...     ...     ...
# 621   AQSH parchalanadimi? Sobiq prezident Donald Tr...  0.0000  0.0000
# 622   Islomda payg'ambarning har qanday tasviri, hat...  0.0000  0.0000
# 703   Hukumatning Istanbul bo'yicha natijalarni qayt...  0.0000  0.0000
# 704   Asli buxorolik Anvarov soxta pasport bilan Mar...  0.0000  0.0000
# 626   Rossiya Federatsiyasi Kengashi Prezident Putin...  0.0000  0.0000
#
#       sequence_similarity  ref_word_count  hyp_word_count
# id
# 1997               0.6667               2               2
# 1193               0.9231               2               2
# 1880               0.7826               2               2
# 369                0.9143               2               2
# 1967               0.8483              21              19
# ...                   ...             ...             ...
# 621                1.0000              18              18
# 622                1.0000              16              16
# 703                1.0000              11              11
# 704                1.0000              14              14
# 626                1.0000              12              12
#
# [1144 rows x 13 columns]

# %%
mask = feruza_speech_df["wer"] > 0.0
total_duration_affected = feruza_speech_df[mask]["duration"].sum() / 3600
total_duration = feruza_speech_df["duration"].sum() / 3600

feruza_speech_df.loc[mask, "ref_normalized"] = feruza_speech_df.loc[mask, "hyp_normalized"]
feruza_speech_df.loc[mask, "wer"] = 0.0
feruza_speech_df.loc[mask, "cer"] = 0.0
feruza_speech_df.loc[mask, "sequence_similarity"] = 1.0
feruza_speech_df.loc[mask, "ref_word_count"] = feruza_speech_df.loc[mask, "hyp_word_count"]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
feruza_speech_df.to_csv("feruza_speech_modified_part1.csv", index_label="id")
# Out:
# Total duration affected: 2.45 hours (out of 4.39 hours)

# %%
common_voice_df = pd.read_csv("common_voice_part1.csv", index_col="id")
common_voice_df.drop(columns={"speaker_trust_score"}, inplace=True)
common_voice_df.rename(
    columns={"sentence": "text_original", "predicted_sentence": "text_spt", "client_id": "speaker_id"},
    inplace=True
)

# Rename dataset type: dev -> validation
common_voice_df["type"] = common_voice_df["type"].replace("dev", "validation")
common_voice_df["path"] = common_voice_df["path"].str.replace(r".mp3$", ".wav", regex=True)

# Reorder text_original column to be one before the last column
cols = list(common_voice_df.columns)
cols.remove("text_original")
cols.insert(10, "text_original")
cols.remove("text_spt")
cols.insert(11, "text_spt")
cols.remove("speaker_id")
cols.insert(1, "speaker_id")
common_voice_df = common_voice_df[cols]

common_voice_df["path"] = common_voice_df["path"].str.replace(r".mp3$", ".wav", regex=True)

common_voice_df = apply_similarity_metrics(common_voice_df)
common_voice_df
# Out:
#                               path  \
# id
# 7571  common_voice_uz_28892774.wav
# 6553  common_voice_uz_29492915.wav
# 6707  common_voice_uz_29659552.wav
# 5145  common_voice_uz_29771945.wav
# 6526  common_voice_uz_28894630.wav
# ...                            ...
# 4632  common_voice_uz_28828269.wav
# 4634  common_voice_uz_28903020.wav
# 1913  common_voice_uz_30657618.wav
# 4618  common_voice_uz_29116185.wav
# 4596  common_voice_uz_28924135.wav
#
#                                              speaker_id  \
# id
# 7571  633f4e362252d4c478e27f908b68480f89933e92839bb0...
# 6553  aa6ecc7fd43b0bd12a2ef4265a218102d3c964d4c19e96...
# 6707  c9ca42351a125d9d954efb587e6965622b120307845e4a...
# 5145  65701bd746d41eb89b41eeac8caeb46055c868dafda4d8...
# 6526  72f41c6b4733d93836e0def2d211362ac6db2632ea326a...
# ...                                                 ...
# 4632  bd299afdd61c7e10f6352a24b16206e2e97339a36777a3...
# 4634  cbe9f3a0053bef07470f5179a26f992986f75403738e79...
# 1913  793fe0ce43a754a201704b36515c39acc4c902366c6dde...
# 4618  8c6aad4b38297f2e3f1f1e6f10b7bb69af360c432a043c...
# 4596  cc7bdaa70930c795eda78822eea4fe1bf9a477ea75f3e0...
#
#                                             sentence_id  up_votes  down_votes  \
# id
# 7571  a5356ceefe726034a0742413320f4c76f853b887750144...         2           0
# 6553  2df183e98e1caf5e45b1d65b9c76b2d9d7e64e4f54e75d...         2           0
# 6707  4874e1acfcf4e5aa96de55672fc4dbcee42d1364523702...         2           0
# 5145  607d988fb82cb3827f5413756cdfad582e5f66145fe46a...         2           0
# 6526  b353ac590bcd763f95225d405a6b7451a571a53eff16b9...         2           0
# ...                                                 ...       ...         ...
# 4632  3634596e8202fc0729249ecb56d5f78fd635da7b704e5f...         2           0
# 4634  7e90a30314927ba70b5b4cc227a10c642f33c6fb2c70ec...         2           0
# 1913  0fed99a28f21ba7d1a4ed8d947163f51e2f04341fe9d5e...         0           0
# 4618  881a8775dd7344930fcbb16f8822b48258f03991421d0a...         2           0
# 4596  e7619784bc930f29c785830bb1993628e9587f32211a0f...         2           0
#
#            age           gender   type  duration  word_count  \
# id
# 7571  twenties   male_masculine  train     3.456           2
# 6553       NaN              NaN   test     3.420           2
# 6707     teens   male_masculine   test     3.708           2
# 5145       NaN              NaN   test     4.320           2
# 6526     teens  female_feminine  train     3.780           3
# ...        ...              ...    ...       ...         ...
# 4632     teens   male_masculine   test     5.148           5
# 4634       NaN              NaN   test     4.940           5
# 1913  twenties   male_masculine  train     6.050           8
# 4618       NaN              NaN   test     6.120           6
# 4596  twenties   male_masculine  train     7.668           7
#
#                                           text_original  \
# id
# 7571                           O'g'illarini uylantirdi.
# 6553                                    Ayniqsa, oyimni
# 6707                                O'rgatib oldingizmi
# 5145                                  Kelajagi, davomi.
# 6526                                 O'n yettinchi asr.
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                                text_spt  \
# id
# 7571                            o'g'illarini uylantirdi
# 6553                                    Ayniqsa oyimni.
# 6707                               o'rgatib oldingizmi?
# 5145                                    kelajagi davomi
# 6526                                             17-asr
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                          ref_normalized  \
# id
# 7571                           O'g'illarini uylantirdi.
# 6553                                    Ayniqsa, oyimni
# 6707                                O'rgatib oldingizmi
# 5145                                  Kelajagi, davomi.
# 6526                                 O'n yettinchi asr.
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                          hyp_normalized  wer     cer  \
# id
# 7571                            o'g'illarini uylantirdi  1.0  0.0833
# 6553                                    Ayniqsa oyimni.  1.0  0.1333
# 6707                               o'rgatib oldingizmi?  1.0  0.1053
# 5145                                    kelajagi davomi  1.0  0.1765
# 6526                                             17-asr  1.0  0.8333
# ...                                                 ...  ...     ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.  0.0  0.0000
# 4634                     Biz bir muddat yolg'iz qoldik.  0.0  0.0000
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...  0.0  0.0000
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.  0.0  0.0000
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...  0.0  0.0000
#
#       sequence_similarity  ref_word_count  hyp_word_count
# id
# 7571               0.9362               2               2
# 6553               0.9333               2               2
# 6707               0.9231               2               2
# 5145               0.8750               2               2
# 6526               0.2500               3               1
# ...                   ...             ...             ...
# 4632               1.0000               5               5
# 4634               1.0000               5               5
# 1913               1.0000               8               8
# 4618               1.0000               6               6
# 4596               1.0000               7               7
#
# [7631 rows x 19 columns]

# %%
mask = common_voice_df["wer"] > 0.0
total_duration_affected = common_voice_df[mask]["duration"].sum() / 3600
total_duration = common_voice_df["duration"].sum() / 3600

common_voice_df.loc[mask, "ref_normalized"] = common_voice_df.loc[mask, "hyp_normalized"]
common_voice_df.loc[mask, "wer"] = 0.0
common_voice_df.loc[mask, "cer"] = 0.0
common_voice_df.loc[mask, "sequence_similarity"] = 1.0
common_voice_df.loc[mask, "ref_word_count"] = common_voice_df.loc[mask, "hyp_word_count"]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
common_voice_df.to_csv("common_voice_modified_part1.csv", index_label="id")
# Out:
# Total duration affected: 7.83 hours (out of 13.70 hours)

# %%
uzbek_voice_df = pd.read_csv("uzbek_voice_part1.csv", index_col="id")

uzbek_voice_df.drop(columns={"net_votes"}, inplace=True)

uzbek_voice_df
# Out:
#                                   speaker_id        path accent_region  \
# id
# 0       ad974593-4363-49c7-868b-24170166bdbf      37.wav           NaN
# 4       38486d7f-0cdc-43d8-8c04-bcdbf525bbd6      44.wav           NaN
# 5       38486d7f-0cdc-43d8-8c04-bcdbf525bbd6      46.wav           NaN
# 10      d167468f-f3ab-4c21-8da9-b983afe9311b      58.wav      Farg'ona
# 11      d167468f-f3ab-4c21-8da9-b983afe9311b      59.wav      Farg'ona
# ...                                      ...         ...           ...
# 160126  1684927e-c0ee-4208-a6ea-ddc556296815  864857.wav       Andijon
# 160127  1684927e-c0ee-4208-a6ea-ddc556296815  864861.wav       Andijon
# 160128  1684927e-c0ee-4208-a6ea-ddc556296815  864862.wav       Andijon
# 160130  1684927e-c0ee-4208-a6ea-ddc556296815  864865.wav       Andijon
# 160131  fc3d199c-c321-4539-971d-1b8971009ee1  864867.wav        Xorazm
#
#         up_votes  down_votes  reported_count    age          gender  duration  \
# id
# 0             13           0               0    NaN   not_specified     9.576
# 4             16           0               0    NaN   not_specified     6.228
# 5              7           0               0    NaN   not_specified     8.028
# 10             5           0               0  18-24  male_masculine     6.480
# 11             2           0               0  18-24  male_masculine     6.264
# ...          ...         ...             ...    ...             ...       ...
# 160126         0           0               0  25-34  male_masculine     6.048
# 160127         0           0               0  25-34  male_masculine     6.480
# 160128         0           0               0  25-34  male_masculine     8.568
# 160130         0           0               0  25-34  male_masculine     7.488
# 160131         0           0               0  18-24  male_masculine     5.724
#
#         word_count                                      text_original  \
# id
# 0               17  Agar biz chiqarayotgan qaror noto‘g‘ri bo‘lsa,...
# 4               11  O‘zbekistondagi oliy va o‘rta maxsus islom bil...
# 5               15  “Bu Qatar va O‘zbekiston ushbu mushkul davrda ...
# 10               3                              Albatta, u barakadir.
# 11               3                           O‘rtamizda muammo yo‘q”.
# ...            ...                                                ...
# 160126          10  Yer islohoti kutilgan natija berishi uchun yan...
# 160127           9  ba’zi kishilarga mazkur ochiq sudda ishtirok e...
# 160128          11  Sud ibodatxonani buzish haqida qaror chiqardi....
# 160130          10  Olisda tahsil oladigan talabalar saylovda qays...
# 160131           8  Inson tug’ilishidanoq uning miyasida ma’lum da...
#
#                                                  text_spt  \
# id
# 0       Agar biz chiqarayotgan qaror noto‘g‘ri bo‘lsa,...
# 4       O‘zbekistondagi oliy va o‘rta maxsus islom bil...
# 5       “Bu Qatar va O‘zbekiston ushbu mushkul davrda ...
# 10                                  Albatta, u barakadir.
# 11                                 o'rtamizda muammo yo'q
# ...                                                   ...
# 160126  Yer islohoti kutilgan natija berishi uchun yan...
# 160127  Ba'zi kishilarga mazkur ochiq sudda ishtirok e...
# 160128  Sud ibodatxonani buzish haqida qaror chiqardi....
# 160130  Olisda tahsil oladigan talabalar saylovda qays...
# 160131  Inson tug'ilishidanoq uning miyasida ma'lum da...
#
#                                            ref_normalized  \
# id
# 0       agar biz chiqarayotgan qaror noto'g'ri bo'lsa ...
# 4       o'zbekistondagi oliy va o'rta maxsus islom bil...
# 5       bu qatar va o'zbekiston ushbu mushkul davrda b...
# 10                                    albatta u barakadir
# 11                                 o'rtamizda muammo yo'q
# ...                                                   ...
# 160126  yer islohoti kutilgan natija berishi uchun yan...
# 160127  ba'zi kishilarga mazkur ochiq sudda ishtirok e...
# 160128  sud ibodatxonani buzish haqida qaror chiqardi ...
# 160130  olisda tahsil oladigan talabalar saylovda qays...
# 160131  inson tug'ilishidanoq uning miyasida ma'lum da...
#
#                                            hyp_normalized  wer  cer  \
# id
# 0       agar biz chiqarayotgan qaror noto'g'ri bo'lsa ...  0.0  0.0
# 4       o'zbekistondagi oliy va o'rta maxsus islom bil...  0.0  0.0
# 5       bu qatar va o'zbekiston ushbu mushkul davrda b...  0.0  0.0
# 10                                    albatta u barakadir  0.0  0.0
# 11                                 o'rtamizda muammo yo'q  0.0  0.0
# ...                                                   ...  ...  ...
# 160126  yer islohoti kutilgan natija berishi uchun yan...  0.0  0.0
# 160127  ba'zi kishilarga mazkur ochiq sudda ishtirok e...  0.0  0.0
# 160128  sud ibodatxonani buzish haqida qaror chiqardi ...  0.0  0.0
# 160130  olisda tahsil oladigan talabalar saylovda qays...  0.0  0.0
# 160131  inson tug'ilishidanoq uning miyasida ma'lum da...  0.0  0.0
#
#         sequence_similarity  ref_word_count  hyp_word_count        type
# id
# 0                       1.0              17              17        test
# 4                       1.0              11              11       train
# 5                       1.0              15              15       train
# 10                      1.0               3               3       train
# 11                      1.0               3               3       train
# ...                     ...             ...             ...         ...
# 160126                  1.0              10              10  validation
# 160127                  1.0               9               9  validation
# 160128                  1.0              11              11  validation
# 160130                  1.0              10              10  validation
# 160131                  1.0               8               8       train
#
# [98692 rows x 20 columns]

# %%
# Example: O‘ylashimcha, hammasi yaxshilikka”, deydi Jaloliddinov.
trailing_quote_mask = uzbek_voice_df["text_spt"].str.contains(r"(^[^“]*)”([^“]*$)", regex=True)
matched = uzbek_voice_df[trailing_quote_mask][["path", "text_original", "text_spt", "ref_normalized"]]

uzbek_voice_df["text_spt"] = uzbek_voice_df["text_spt"].str.replace(
    r"(^[^“]*)”([^“]*$)",
    r"\1\2",
    regex=True
)
uzbek_voice_df.loc[trailing_quote_mask, "text_original"] = uzbek_voice_df.loc[
    trailing_quote_mask, "text_original"].str.replace(
    r"(^[^“]*)”([^“]*$)",
    r"\1\2",
    regex=True
)

matched
# Out:
# /tmp/ipykernel_904369/1253041954.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   trailing_quote_mask = uzbek_voice_df["text_spt"].str.contains(r"(^[^“]*)”([^“]*$)", regex=True)
#               path                                      text_original  \
# id
# 32         243.wav                         Bo‘lmasa, o‘zingni o‘yla”.
# 86         721.wav                             Shuning o‘zi yetarli”.
# 152       2367.wav                        Bundan judayam xursandman”.
# 3209     52636.wav  Istalgan turdagi zo‘ravonlikka”, deydi Infantino.
# 3339     53711.wav  O‘ylashimcha, hammasi yaxshilikka”, deydi Jalo...
# ...            ...                                                ...
# 100431  482680.wav  Bozor talabini o‘rganib, aql bilan ish tutilsa...
# 102932  489291.wav  Hamma ishlar aholining roziligi olinmasdan qil...
# 104184  493115.wav  Aslida, o‘zbekchilikning zamirida beg‘ubor g‘o...
# 104671  494748.wav  Avtomobil harakati to‘xtatilgan, aylanib o‘tad...
# 117015  638157.wav  Nimayam derdim, shunchaki hamkorlar bo‘lamiz”,...
#
#                                                  text_spt  \
# id
# 32                             Bo‘lmasa, o‘zingni o‘yla”.
# 86                                 Shuning o‘zi yetarli”.
# 152                           Bundan judayam xursandman”.
# 3209    Istalgan turdagi zo‘ravonlikka”, deydi Infantino.
# 3339    O‘ylashimcha, hammasi yaxshilikka”, deydi Jalo...
# ...                                                   ...
# 100431  Bozor talabini o‘rganib, aql bilan ish tutilsa...
# 102932  Hamma ishlar aholining roziligi olinmasdan qil...
# 104184  Aslida, o‘zbekchilikning zamirida beg‘ubor g‘o...
# 104671  Avtomobil harakati to‘xtatilgan, aylanib o‘tad...
# 117015  Nimayam derdim, shunchaki hamkorlar bo‘lamiz”,...
#
#                                            ref_normalized
# id
# 32                                bo'lmasa o'zingni o'yla
# 86                                   shuning o'zi yetarli
# 152                             bundan judayam xursandman
# 3209       istalgan turdagi zo'ravonlikka deydi infantino
# 3339    o'ylashimcha hammasi yaxshilikka deydi jalolid...
# ...                                                   ...
# 100431  bozor talabini o'rganib aql bilan ish tutilsa ...
# 102932  hamma ishlar aholining roziligi olinmasdan qil...
# 104184  aslida o'zbekchilikning zamirida beg'ubor g'oy...
# 104671  avtomobil harakati to'xtatilgan aylanib o'tadi...
# 117015  nimayam derdim shunchaki hamkorlar bo'lamiz de...
#
# [187 rows x 4 columns]

# %%
# Examples: 8 677 960, 971 483, 1 483
only_numbers_mask = uzbek_voice_df["text_spt"].str.contains(r"^(\d+(?: \d{3})*)$", regex=True)
matched = uzbek_voice_df[only_numbers_mask][["path", "text_original", "text_spt", "ref_normalized"]]

uzbek_voice_df.loc[only_numbers_mask, "text_spt"] = uzbek_voice_df.loc[only_numbers_mask, "text_original"]

uzbek_voice_df.to_csv("uzbek_voice_modified_part1.csv", index_label="id")
matched
# Out:
# /tmp/ipykernel_904369/2463319546.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   only_numbers_mask = uzbek_voice_df["text_spt"].str.contains(r"^(\d+(?: \d{3})*)$", regex=True)
#               path text_original text_spt  \
# id
# 157197  855102.wav        58 025    58025
# 157198  855104.wav       118 275   118275
# 157199  855106.wav       623 261   623261
# 157257  855290.wav           547      547
# 157258  855291.wav        71 004    71004
# ...            ...           ...      ...
# 159365  862942.wav       400 942  400 942
# 159390  863008.wav        61 619    61619
# 159391  863009.wav        85 049    85049
# 159392  863016.wav       154 048   154048
# 159393  863017.wav       224 045   224045
#
#                                         ref_normalized
# id
# 157197                  ellik sakkiz ming yigirma besh
# 157198   bir yuz o'n sakkiz ming ikki yuz yetmish besh
# 157199  olti yuz yigirma uch ming ikki yuz oltmish bir
# 157257                             besh yuz qirq yetti
# 157258                          yetmish bir ming to'rt
# ...                                                ...
# 159365            to'rt yuz ming to'qqiz yuz qirq ikki
# 159390           oltmish bir ming olti yuz o'n to'qqiz
# 159391                   sakson besh ming qirq to'qqiz
# 159392            bir yuz ellik to'rt ming qirq sakkiz
# 159393           ikki yuz yigirma to'rt ming qirq besh
#
# [699 rows x 4 columns]

# %%
uzbek_voice_df = apply_similarity_metrics(uzbek_voice_df)
uzbek_voice_df
# Out:
#                                   speaker_id        path      accent_region  \
# id
# 153286  98e24f95-d78e-4d77-bd69-c609d37cb9e0  844366.wav             Xorazm
# 43189   254a9c0a-5ca9-4ef0-8ab3-153b7e046391  206198.wav            Andijon
# 44991   b91829a7-6143-4da2-bd09-294a83c519ab  266309.wav             Jizzax
# 43163   a6ee9346-27a0-4500-8671-f6aa7184fd8f  205344.wav  Toshkent viloyati
# 96      423c0258-88cf-48d9-8861-3ef95ce23bd5     986.wav           Farg'ona
# ...                                      ...         ...                ...
# 73779   3c9ce934-07cb-40c0-9b02-c4186f2b1bfd  411191.wav             Jizzax
# 73778   2f9b459c-009e-4fb2-b3c9-3a7d1d119179  411188.wav             Jizzax
# 73775   ce7fe857-d368-48e7-9dcb-b107aa0d1572  411181.wav             Navoiy
# 73774   bfc238d1-ec67-42b3-8012-121f9f806c9a  411180.wav           Farg'ona
# 73886   66cfbf16-f1c2-4ca3-a26e-b0aa28ed2f8f  411486.wav            Andijon
#
#         up_votes  down_votes  reported_count     age           gender  \
# id
# 153286         0           0               0    < 19   male_masculine
# 43189          0           0               0   19-29  female_feminine
# 44991          2           0               0    < 19  female_feminine
# 43163          0           0               0   30-39   male_masculine
# 96             4           0               0   18-24  female_feminine
# ...          ...         ...             ...     ...              ...
# 73779          0           0               0   25-34   male_masculine
# 73778          0           0               0   18-24  female_feminine
# 73775          0           0               0    < 19  female_feminine
# 73774          0           0               0   12-17   male_masculine
# 73886          0           0               0  35-...   male_masculine
#
#         duration  word_count  \
# id
# 153286     3.168           2
# 43189      3.420           3
# 44991      5.004           5
# 43163      3.384           3
# 96         3.960           3
# ...          ...         ...
# 73779      5.472           9
# 73778      5.940           9
# 73775      5.904           9
# 73774      6.804           9
# 73886      6.336           9
#
#                                             text_original  \
# id
# 153286                          Kechiraman anqovligini.\r
# 43189                        Haqiqiy partiyalar, albatta.
# 44991   Darvozabonlar: Himoyachilar: Yarim himoyachila...
# 43163                        Mashinamda Chashmaga bordim.
# 96                                   “Mening yoshim 28da.
# ...                                                   ...
# 73779   Nima sababdan tartibga solish ishlari oldingid...
# 73778   O‘zbekistonlik ingliz tili o‘qituvchilari Buyu...
# 73775   Samarqand viloyati Bulung‘ur tumaniga Xayriddi...
# 73774   Janubiy Uels politsiyasi vakiliga ko‘ra, hodis...
# 73886   Narimon Umarov Toshkent va Sirdaryo viloyatlar...
#
#                                                  text_spt   type  \
# id
# 153286                             kechiraman anqovligini  train
# 43189                          haqiqiy partiyalar albatta  train
# 44991   darvozabonlar, himoyachilar, yarim himoyachila...  train
# 43163                         mashinamda chashmaga bordim  train
# 96                                   Mening yoshim 28 da.  train
# ...                                                   ...    ...
# 73779   Nima sababdan tartibga solish ishlari oldingid...  train
# 73778   O'zbekistonlik ingliz tili o'qituvchilari Buyu...  train
# 73775   Samarqand viloyati Bulung'ur tumaniga Xayriddi...  train
# 73774   Janubiy Uels politsiyasi vakiliga ko'ra, hodis...  train
# 73886   Narimon Umarov Toshkent va Sirdaryo viloyatlar...  train
#
#                                            ref_normalized  \
# id
# 153286                            Kechiraman anqovligini.
# 43189                        Haqiqiy partiyalar, albatta.
# 44991   Darvozabonlar: Himoyachilar: Yarim himoyachila...
# 43163                        Mashinamda Chashmaga bordim.
# 96                                   "Mening yoshim 28da.
# ...                                                   ...
# 73779   Nima sababdan tartibga solish ishlari oldingid...
# 73778   O'zbekistonlik ingliz tili o'qituvchilari Buyu...
# 73775   Samarqand viloyati Bulung'ur tumaniga Xayriddi...
# 73774   Janubiy Uels politsiyasi vakiliga ko'ra, hodis...
# 73886   Narimon Umarov Toshkent va Sirdaryo viloyatlar...
#
#                                            hyp_normalized  wer     cer  \
# id
# 153286                             kechiraman anqovligini  1.0  0.0870
# 43189                          haqiqiy partiyalar albatta  1.0  0.1071
# 44991   darvozabonlar, himoyachilar, yarim himoyachila...  1.0  0.1311
# 43163                         mashinamda chashmaga bordim  1.0  0.1071
# 96                                   Mening yoshim 28 da.  1.0  0.1000
# ...                                                   ...  ...     ...
# 73779   Nima sababdan tartibga solish ishlari oldingid...  0.0  0.0000
# 73778   O'zbekistonlik ingliz tili o'qituvchilari Buyu...  0.0  0.0000
# 73775   Samarqand viloyati Bulung'ur tumaniga Xayriddi...  0.0  0.0000
# 73774   Janubiy Uels politsiyasi vakiliga ko'ra, hodis...  0.0  0.0000
# 73886   Narimon Umarov Toshkent va Sirdaryo viloyatlar...  0.0  0.0000
#
#         sequence_similarity  ref_word_count  hyp_word_count
# id
# 153286               0.9333               2               2
# 43189                0.9259               3               3
# 44991                0.8760               5               5
# 43163                0.9091               3               3
# 96                   0.9500               3               4
# ...                     ...             ...             ...
# 73779                1.0000               9               9
# 73778                1.0000               9               9
# 73775                1.0000               9               9
# 73774                1.0000               9               9
# 73886                1.0000               9               9
#
# [98692 rows x 20 columns]

# %%
uzbek_voice_df = uzbek_voice_df[~uzbek_voice_df.duplicated(subset=["path", "speaker_id"], keep="first")]

mask = uzbek_voice_df["wer"] > 0.0
total_duration_affected = uzbek_voice_df[mask]["duration"].sum() / 3600
total_duration = uzbek_voice_df["duration"].sum() / 3600

uzbek_voice_df.loc[mask, "ref_normalized"] = uzbek_voice_df.loc[mask, "hyp_normalized"]
uzbek_voice_df.loc[mask, "wer"] = 0.0
uzbek_voice_df.loc[mask, "cer"] = 0.0
uzbek_voice_df.loc[mask, "sequence_similarity"] = 1.0
uzbek_voice_df.loc[mask, "ref_word_count"] = uzbek_voice_df.loc[mask, "hyp_word_count"]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
uzbek_voice_df.to_csv("uzbek_voice_modified_part1.csv", index_label="id")
# Out:
# Total duration affected: 45.67 hours (out of 153.08 hours)

# %%
news_df = pd.read_csv("news_dataset_part1.csv", index_col="id")

# Swap places of text_spt (Google STT generated as reference) -> text_original (Gemini 2.5 Pro generated as hypothesis)
# Because apply_similarity_metrics method assumes text_original as reference
news_df.rename(
    columns={"text_spt": "text_original", "text_original": "text_spt"},
    inplace=True
)

news_df = apply_similarity_metrics(news_df)
news_df
# Out:
#                  path   duration   type  char_count  word_count  \
# id
# 870      00010327.wav   9.861375  train       145.0        22.0
# 2943   00011002_0.wav   6.870000  train         NaN         NaN
# 14514  00010386_0.wav  13.880000  train         NaN         NaN
# 2025   00004302_0.wav   6.740000  train         NaN         NaN
# 12940  00005602_0.wav  11.030000  train         NaN         NaN
# ...               ...        ...    ...         ...         ...
# 1195     00015156.wav  18.981313  train       230.0        30.0
# 1887     00020236.wav   8.314687   test         NaN         NaN
# 1872     00019149.wav  12.240000   test         NaN         NaN
# 905      00010751.wav  16.976000  train       198.0        25.0
# 1989     00016295.wav  12.965375   test         NaN         NaN
#
#                                            text_original  \
# id
# 870    3685 so'm, Saidullayev Akmal Yuldashevichdan 3...
# 2943                       pul chiqyapti 19 660 400 so'm
# 14514  Azamatovichdan 36 112 622 so'm, Abdujabborov B...
# 2025                           tashkil etuvchi 5 450 500
# 12940  Siz lang'an ekansiz-u. 59-moddaning 6-qismiga ...
# ...                                                  ...
# 1195   javob qaytaraverdi. Isroil hududining birgina ...
# 1887   bizlar hurmat qilamiz. Iloji boricha bizlar to...
# 1872   Hammasi bir narsaga bog'liqki, o'sha yelkadagi...
# 905    Bizda ham mana shunday choralarni qo'llash vaq...
# 1989   Men hali bularga yana qo'shimcha ravishda yana...
#
#                                                 text_spt  \
# id
# 870    son uch ming olti yuz sakson besh so'm. Saidul...
# 2943   a-a pul chiqyapti o'n to'qqiz million olti yuz...
# 14514  Azamatovichdan o'ttiz olti million bir yuz o'n...
# 2025   ni tashkil etuvchi besh million toʻrt yuz elli...
# 12940  Ya'ni sudlangan ekansiz-u. Ellik to'qqizinchi ...
# ...                                                  ...
# 1195   javob qaytaraverdi. Isroil hududining birgina ...
# 1887   bizlar hurmat qilamiz. Iloji boricha bizlar to...
# 1872   Hammasi bir narsaga bog'liqki, o'sha yelkadagi...
# 905    Bizda ham mana shunday choralarni qoʻllash vaq...
# 1989   Men hali bularga yana qo'shimcha ravishda yana...
#
#                                           ref_normalized  \
# id
# 870    3685 so'm, Saidullayev Akmal Yuldashevichdan 3...
# 2943                       pul chiqyapti 19 660 400 so'm
# 14514  Azamatovichdan 36 112 622 so'm, Abdujabborov B...
# 2025                           tashkil etuvchi 5 450 500
# 12940  Siz lang'an ekansiz-u. 59-moddaning 6-qismiga ...
# ...                                                  ...
# 1195   javob qaytaraverdi. Isroil hududining birgina ...
# 1887   bizlar hurmat qilamiz. Iloji boricha bizlar to...
# 1872   Hammasi bir narsaga bog'liqki, o'sha yelkadagi...
# 905    Bizda ham mana shunday choralarni qo'llash vaq...
# 1989   Men hali bularga yana qo'shimcha ravishda yana...
#
#                                           hyp_normalized     wer     cer  \
# id
# 870    son uch ming olti yuz sakson besh so'm. Saidul...  2.1111  1.6230
# 2943   a-a pul chiqyapti o'n to'qqiz million olti yuz...  1.8333  1.8621
# 14514  Azamatovichdan o'ttiz olti million bir yuz o'n...  1.6471  0.9609
# 2025   ni tashkil etuvchi besh million to'rt yuz elli...  1.6000  1.5600
# 12940  Ya'ni sudlangan ekansiz-u. Ellik to'qqizinchi ...  1.4667  0.8871
# ...                                                  ...     ...     ...
# 1195   javob qaytaraverdi. Isroil hududining birgina ...  0.0000  0.0000
# 1887   bizlar hurmat qilamiz. Iloji boricha bizlar to...  0.0000  0.0000
# 1872   Hammasi bir narsaga bog'liqki, o'sha yelkadagi...  0.0000  0.0000
# 905    Bizda ham mana shunday choralarni qo'llash vaq...  0.0000  0.0000
# 1989   Men hali bularga yana qo'shimcha ravishda yana...  0.0000  0.0000
#
#        sequence_similarity  ref_word_count  hyp_word_count
# id
# 870                 0.4466               9              22
# 2943                0.4038               6              13
# 14514               0.4693              17              35
# 2025                0.4390               5              10
# 12940               0.1731              15              28
# ...                    ...             ...             ...
# 1195                1.0000              30              30
# 1887                1.0000              14              14
# 1872                1.0000              22              22
# 905                 1.0000              25              25
# 1989                1.0000              22              22
#
# [15140 rows x 14 columns]

# %%
mask = news_df["wer"] > 0.0
not_aligned_duration = news_df[mask]["duration"].sum() / 3600
total_duration = news_df["duration"].sum() / 3600

print("Nothing changed here.")
print(f"Not aligned total duration: {not_aligned_duration:.2f} hours (out of {total_duration:.2f} hours)")
news_df.to_csv("news_dataset_modified_part1.csv", index_label="id")
# Out:
# Nothing changed here.
# Not aligned total duration: 64.85 hours (out of 65.72 hours)

# %%
it_df = pd.read_csv("it_dataset_part1.csv", index_col="id")

# Swap places of text_spt (Google STT generated as reference) -> text_original (Gemini 2.5 Pro generated as hypothesis)
# Because apply_similarity_metrics method assumes text_original as reference
it_df.rename(
    columns={"text_spt": "text_original", "text_original": "text_spt"},
    inplace=True
)

it_df = apply_similarity_metrics(it_df)
it_df
# Out:
#            path   duration   type  char_count  word_count  \
# id
# 1237  15964.wav  10.224000  train        52.0         7.0
# 856   10305.wav   7.480000  train        54.0         7.0
# 184   02338.wav   6.714688  train        57.0         7.0
# 827   09757.wav   7.304688  train        69.0         9.0
# 1252  16134.wav  17.946687  train       272.0        39.0
# ...         ...        ...    ...         ...         ...
# 694   08120.wav  18.266687  train       126.0        17.0
# 617   06752.wav   6.930000  train        68.0         9.0
# 619   06769.wav  18.394687  train       257.0        33.0
# 625   06831.wav   6.180000  train        60.0         8.0
# 2036  08556.wav  13.451375   test         NaN         NaN
#
#                                           text_original  \
# id
# 1237          savolingiz uchun rahmat, bu narsalar o'zi
# 856   Nima deydi? Tajribada orttiriladigan bir skill...
# 184   shunaqa tavsiya qilgan bo'lardim shunaqa qilis...
# 827   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 1252  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# ...                                                 ...
# 694   yoshi kattalar haqida so'rashgan ekan. Yoshi k...
# 617   uchun doimiy yashovchi rezident sifatida viza ...
# 619   lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 625   kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 2036  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                                text_spt  \
# id
# 1237  Rahmat. Savolingiz uchun rahmat. Bu narsalar o...
# 856   nima deydi, tajribada orttiriladigan bir skill...
# 184   dedik. Shunaqa tavsiya qilgan bo'lardim. Shuna...
# 827   Assalomu alaykum. Ismim Botirjon, familiyam Ha...
# 1252  bu start ikki ming yigirma ikkinchi yilgacha h...
# ...                                                 ...
# 694   yoshi kattalar haqida so'rashgan ekan. yoshi k...
# 617   uchun doimiy yashovchi rezident sifatida viza ...
# 619   lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 625   kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 2036  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                          ref_normalized  \
# id
# 1237          savolingiz uchun rahmat, bu narsalar o'zi
# 856   Nima deydi? Tajribada orttiriladigan bir skill...
# 184   shunaqa tavsiya qilgan bo'lardim shunaqa qilis...
# 827   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 1252  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# ...                                                 ...
# 694   yoshi kattalar haqida so'rashgan ekan. Yoshi k...
# 617   uchun doimiy yashovchi rezident sifatida viza ...
# 619   lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 625   kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 2036  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                          hyp_normalized     wer     cer  \
# id
# 1237  Rahmat. Savolingiz uchun rahmat. Bu narsalar o...  0.8333  0.3415
# 856   nima deydi, tajribada orttiriladigan bir skill...  0.8333  0.1400
# 184   dedik. Shunaqa tavsiya qilgan bo'lardim. Shuna...  0.8333  0.2200
# 827   Assalomu alaykum. Ismim Botirjon, familiyam Ha...  0.7500  0.0735
# 1252  bu start ikki ming yigirma ikkinchi yilgacha h...  0.7000  0.3009
# ...                                                 ...     ...     ...
# 694   yoshi kattalar haqida so'rashgan ekan. Yoshi k...  0.0000  0.0000
# 617   uchun doimiy yashovchi rezident sifatida viza ...  0.0000  0.0000
# 619   lekin shunaqa jarayon bo'lsa ham, lekin starta...  0.0000  0.0000
# 625   kelajakdagi ulkan bir yutuqqa olib kelishini. ...  0.0000  0.0000
# 2036  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...  0.0000  0.0000
#
#       sequence_similarity  ref_word_count  hyp_word_count
# id
# 1237               0.8172               6               7
# 856                0.9038               6               7
# 184                0.8785               6               7
# 827                0.9343               8               9
# 1252               0.1647              30              39
# ...                   ...             ...             ...
# 694                1.0000              17              17
# 617                1.0000               9               9
# 619                1.0000              33              33
# 625                1.0000               8               8
# 2036               1.0000              10              10
#
# [2038 rows x 14 columns]

# %%
mask = it_df["wer"] > 0.0
not_aligned_duration = it_df[mask]["duration"].sum() / 3600
total_duration = it_df["duration"].sum() / 3600

print("Nothing changed here.")
print(f"Not aligned total duration: {not_aligned_duration:.2f} hours (out of {total_duration:.2f} hours)")
it_df.to_csv("it_dataset_modified_part1.csv", index_label="id")
# Out:
# Nothing changed here.
# Not aligned total duration: 7.73 hours (out of 8.13 hours)

# %% [markdown]
# ## Combine All Case Sensitive Datasets

# %%
feruza_speech_df = pd.read_csv("feruza_speech_modified_part1.csv", index_col="id")
common_voice_df = pd.read_csv("common_voice_modified_part1.csv", index_col="id")
uzbek_voice_df = pd.read_csv("uzbek_voice_modified_part1.csv", index_col="id")
news_df = pd.read_csv("news_dataset_modified_part1.csv", index_col="id")
it_df = pd.read_csv("it_dataset_modified_part1.csv", index_col="id")

feruza_speech_df["dataset"] = "feruza_speech"
common_voice_df["dataset"] = "common_voice"
uzbek_voice_df["dataset"] = "uzbek_voice"
news_df["dataset"] = "news"
it_df["dataset"] = "it"

# Reorder dataset column
combined_case_sensitive_df = pd.concat(
    [feruza_speech_df, common_voice_df, uzbek_voice_df, news_df, it_df],
    axis=0,
    ignore_index=True
)
cols = list(combined_case_sensitive_df.columns)
cols.remove("dataset")
cols.insert(2, "dataset")
cols.remove("word_count")
cols.insert(-1, "word_count")
cols.remove("char_count")
combined_case_sensitive_df = combined_case_sensitive_df[cols]

combined_case_sensitive_df.to_csv("combined__case_sensitive_part1.csv", index_label="id")
combined_case_sensitive_df
# Out:
#                path        type        dataset   duration  \
# 0        029-92.wav  validation  feruza_speech   5.500063
# 1       1055-86.wav       train  feruza_speech   4.132000
# 2        026-01.wav  validation  feruza_speech   3.380000
# 3       1059-77.wav       train  feruza_speech   5.367563
# 4       029-105.wav  validation  feruza_speech  18.548500
# ...             ...         ...            ...        ...
# 124625    08120.wav       train             it  18.266687
# 124626    06752.wav       train             it   6.930000
# 124627    06769.wav       train             it  18.394687
# 124628    06831.wav       train             it   6.180000
# 124629    08556.wav        test             it  13.451375
#
#                                             text_original  \
# 0                                           CH..., 1-may.
# 1                                    So'nggi tafsilotlar.
# 2                                          B..., 19-mart.
# 3                                      Aloqador mavzular:
# 4       — Unda o'n to'qqiz, mayli, o'n sakkiz ham bo'l...
# ...                                                   ...
# 124625  yoshi kattalar haqida so'rashgan ekan. Yoshi k...
# 124626  uchun doimiy yashovchi rezident sifatida viza ...
# 124627  lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 124628  kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 124629  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                                  text_spt  \
# 0                                                Ch 1-may
# 1                                     so'nggi tafsilotlar
# 2                                               B 19-mart
# 3                                       aloqador mavzular
# 4       Unda 19, mayli 18 ham bo'lsin. Indamaysan-a, k...
# ...                                                   ...
# 124625  yoshi kattalar haqida so'rashgan ekan. yoshi k...
# 124626  uchun doimiy yashovchi rezident sifatida viza ...
# 124627  lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 124628  kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 124629  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                            ref_normalized  \
# 0                                                Ch 1-may
# 1                                     so'nggi tafsilotlar
# 2                                               B 19-mart
# 3                                       aloqador mavzular
# 4       Unda 19, mayli 18 ham bo'lsin. Indamaysan-a, k...
# ...                                                   ...
# 124625  yoshi kattalar haqida so'rashgan ekan. Yoshi k...
# 124626  uchun doimiy yashovchi rezident sifatida viza ...
# 124627  lekin shunaqa jarayon bo'lsa ham, lekin starta...
# 124628  kelajakdagi ulkan bir yutuqqa olib kelishini. ...
# 124629  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...
#
#                                            hyp_normalized  wer  cer  ...  \
# 0                                                Ch 1-may  0.0  0.0  ...
# 1                                     so'nggi tafsilotlar  0.0  0.0  ...
# 2                                               B 19-mart  0.0  0.0  ...
# 3                                       aloqador mavzular  0.0  0.0  ...
# 4       Unda 19, mayli 18 ham bo'lsin. Indamaysan-a, k...  0.0  0.0  ...
# ...                                                   ...  ...  ...  ...
# 124625  yoshi kattalar haqida so'rashgan ekan. Yoshi k...  0.0  0.0  ...
# 124626  uchun doimiy yashovchi rezident sifatida viza ...  0.0  0.0  ...
# 124627  lekin shunaqa jarayon bo'lsa ham, lekin starta...  0.0  0.0  ...
# 124628  kelajakdagi ulkan bir yutuqqa olib kelishini. ...  0.0  0.0  ...
# 124629  Suhbatlardan o'tish eng asosiy, eng oxirgi nim...  0.0  0.0  ...
#
#         hyp_word_count  speaker_id  sentence_id up_votes down_votes  age  \
# 0                    2         NaN          NaN      NaN        NaN  NaN
# 1                    2         NaN          NaN      NaN        NaN  NaN
# 2                    2         NaN          NaN      NaN        NaN  NaN
# 3                    2         NaN          NaN      NaN        NaN  NaN
# 4                   19         NaN          NaN      NaN        NaN  NaN
# ...                ...         ...          ...      ...        ...  ...
# 124625              17         NaN          NaN      NaN        NaN  NaN
# 124626               9         NaN          NaN      NaN        NaN  NaN
# 124627              33         NaN          NaN      NaN        NaN  NaN
# 124628               8         NaN          NaN      NaN        NaN  NaN
# 124629              10         NaN          NaN      NaN        NaN  NaN
#
#         gender accent_region reported_count word_count
# 0          NaN           NaN            NaN        3.0
# 1          NaN           NaN            NaN        2.0
# 2          NaN           NaN            NaN        3.0
# 3          NaN           NaN            NaN        2.0
# 4          NaN           NaN            NaN       22.0
# ...        ...           ...            ...        ...
# 124625     NaN           NaN            NaN       17.0
# 124626     NaN           NaN            NaN        9.0
# 124627     NaN           NaN            NaN       33.0
# 124628     NaN           NaN            NaN        8.0
# 124629     NaN           NaN            NaN        NaN
#
# [124630 rows x 22 columns]

# %%
combined_case_sensitive_df.describe(include="all")
# Out:
#              path    type      dataset       duration text_original  text_spt  \
# count      124630  124630       124630  124630.000000        124630    124630
# unique     124607       3            5            NaN        109167    110685
# top     19219.wav   train  uzbek_voice            NaN      [musiqa]  [musiqa]
# freq            2  111799        98677            NaN            67        30
# mean          NaN     NaN          NaN       7.077386           NaN       NaN
# std           NaN     NaN          NaN       4.428000           NaN       NaN
# min           NaN     NaN          NaN       3.010000           NaN       NaN
# 25%           NaN     NaN          NaN       5.148000           NaN       NaN
# 50%           NaN     NaN          NaN       5.652000           NaN       NaN
# 75%           NaN     NaN          NaN       6.696000           NaN       NaN
# max           NaN     NaN          NaN      29.574250           NaN       NaN
#
#        ref_normalized hyp_normalized            wer            cer  ...  \
# count          124630         124630  124630.000000  124630.000000  ...
# unique         109915         109942            NaN            NaN  ...
# top          [musiqa]       [musiqa]            NaN            NaN  ...
# freq               67             66            NaN            NaN  ...
# mean              NaN            NaN       0.028705       0.008428  ...
# std               NaN            NaN       0.084272       0.030890  ...
# min               NaN            NaN       0.000000       0.000000  ...
# 25%               NaN            NaN       0.000000       0.000000  ...
# 50%               NaN            NaN       0.000000       0.000000  ...
# 75%               NaN            NaN       0.000000       0.000000  ...
# max               NaN            NaN       2.111100       1.862100  ...
#
#         hyp_word_count                            speaker_id  \
# count    124630.000000                                106308
# unique             NaN                                  5743
# top                NaN  691f6092-2b2d-411e-a90b-192173ae5e02
# freq               NaN                                   952
# mean         10.963933                                   NaN
# std           9.759774                                   NaN
# min           1.000000                                   NaN
# 25%           7.000000                                   NaN
# 50%           8.000000                                   NaN
# 75%           9.000000                                   NaN
# max          88.000000                                   NaN
#
#                                               sentence_id       up_votes  \
# count                                                7631  106308.000000
# unique                                               6945            NaN
# top     134139c72b0d9fa416750526b99dd8f28dca366daa41f5...            NaN
# freq                                                    4            NaN
# mean                                                  NaN       0.945225
# std                                                   NaN       1.987597
# min                                                   NaN       0.000000
# 25%                                                   NaN       0.000000
# 50%                                                   NaN       0.000000
# 75%                                                   NaN       2.000000
# max                                                   NaN      23.000000
#
#            down_votes     age           gender    accent_region  \
# count   106308.000000  102939           103975            97644
# unique            NaN      18                3               19
# top               NaN   18-24  female_feminine  Toshkent shahri
# freq              NaN   63391            57353            13919
# mean         0.014844     NaN              NaN              NaN
# std          0.126404     NaN              NaN              NaN
# min          0.000000     NaN              NaN              NaN
# 25%          0.000000     NaN              NaN              NaN
# 50%          0.000000     NaN              NaN              NaN
# 75%          0.000000     NaN              NaN              NaN
# max          4.000000     NaN              NaN              NaN
#
#        reported_count     word_count
# count    98677.000000  110819.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean         0.007084       8.447459
# std          0.086718       3.811394
# min          0.000000       1.000000
# 25%          0.000000       7.000000
# 50%          0.000000       8.000000
# 75%          0.000000       9.000000
# max          3.000000      62.000000
#
# [11 rows x 22 columns]

# %%
def print_dataset_statistics(df: pd.DataFrame):
    print(f"At least {df["speaker_id"].nunique():,} speakers involved\n")

    is_training_data_mask = df["type"] == "train"
    total_training_duration = df[is_training_data_mask]["duration"].sum() / 3600
    total_duration = df["duration"].sum() / 3600
    print(
        f"Combined total duration: {total_duration:.2f} hours ({100 * total_training_duration / total_duration:.2f}% is training data)"
    )
    total_training_read_speech_duration = df[df["dataset"].isin(["uzbek_voice", "common_voice", "feruza_speech"]) &
                                             (df["type"] == "train")
                                             ]["duration"].sum() / 3600
    total_training_conversation_speech_duration = df[df["dataset"].isin(["it", "news"]) & (df["type"] == "train")
                                                     ]["duration"].sum() / 3600
    print(
        f"Reed speech training data duration: {total_training_read_speech_duration:.2f} hours ({100 * total_training_read_speech_duration / total_training_duration:.2f}%)"
    )
    print(
        f"Conversation speech training data duration: {total_training_conversation_speech_duration:.2f} hours ({100 * total_training_conversation_speech_duration / total_training_duration:.2f}%)"
    )

    # Overall augmented portion
    is_augmented_mask = df["path"].str.contains("augmented", case=False)
    df["is_augmented"] = is_augmented_mask

    augmented_duration = df[is_augmented_mask & is_training_data_mask]["duration"].sum() / 3600
    print(f"Augmented duration: {augmented_duration:.2f} hours")
    print(f"Augmented portion in training data: {100 * augmented_duration / total_training_duration:.2f}%\n")

    print(df.groupby(["dataset", "type"])["duration"].sum() / 3600)
    print()

    # Augmented vs non-augmented duration per dataset
    print(df.groupby(["dataset", "is_augmented"])["duration"].sum() / 3600)
    print()

    print(df.groupby(["dataset", "gender"], dropna=False)["duration"].sum() / 3600)
    print()

# %%
print_dataset_statistics(combined_case_sensitive_df)
# Out:
# At least 5,743 speakers involved
#
# Combined total duration: 245.02 hours (90.64% is training data)
# Reed speech training data duration: 152.16 hours (68.52%)
# Conversation speech training data duration: 69.91 hours (31.48%)
# Augmented duration: 0.00 hours
# Augmented portion in training data: 0.00%
#
# dataset        type
# common_voice   test            2.751890
#                train           9.617642
#                validation      1.328719
# feruza_speech  test            0.399899
#                train           3.568746
#                validation      0.425895
# it             test            0.737151
#                train           6.654714
#                validation      0.735187
# news           test            1.355555
#                train          63.255186
#                validation      1.106672
# uzbek_voice    test            7.160320
#                train         138.977620
#                validation      6.939970
# Name: duration, dtype: float64
#
# dataset        is_augmented
# common_voice   False            13.698251
# feruza_speech  False             4.394540
# it             False             8.127053
# news           False            65.717414
# uzbek_voice    False           153.077910
# Name: duration, dtype: float64
#
# dataset        gender
# common_voice   female_feminine     1.663659
#                male_masculine      8.050520
#                NaN                 3.984071
# feruza_speech  NaN                 4.394540
# it             NaN                 8.127053
# news           NaN                65.717414
# uzbek_voice    female_feminine    88.269090
#                male_masculine     63.234730
#                not_specified       1.574090
# Name: duration, dtype: float64

# %%
from scripts.dataset_plotting import plot_distribution_graphs

plot_distribution_graphs(combined_case_sensitive_df)

# %% [markdown]
# ## Part 2

# %%
feruza_speech_df = pd.read_csv("feruza_speech_part2.csv", index_col="id")
feruza_speech_df.drop(columns=["text_cyrillic"], inplace=True)
feruza_speech_df.rename(columns={"text_latin": "text_original"}, inplace=True)

# Reorder text_original column to be one before the last column
cols = ["path", "type", "duration", "word_count", "text_original", "text_spt"]
feruza_speech_df = feruza_speech_df[cols]

feruza_speech_df = apply_similarity_metrics(feruza_speech_df)
feruza_speech_df
# Out:
#                               path   type  duration  word_count  \
# id
# 362   029-92_augmented_pch_msk.wav  train    5.5001           3
# 361   029-92_augmented_spd_nse.wav  train    6.9566           3
# 360   029-92_augmented_spd_pch.wav  train    4.4474           3
# 231   026-01_augmented_nse_msk.wav  train    3.3800           3
# 230   026-01_augmented_pch_msk.wav  train    3.3800           3
# ..                             ...    ...       ...         ...
# 373  024-100_augmented_spd_nse.wav  train   24.3619          25
# 372  024-100_augmented_spd_pch.wav  train   22.0008          25
# 371   021-64_augmented_nse_msk.wav  train   15.6000          21
# 370   021-64_augmented_pch_msk.wav  train   15.6000          21
# 379   043-53_augmented_nse_msk.wav  train   14.4419          17
#
#                                          text_original  \
# id
# 362                                      CH..., 1-may.
# 361                                      CH..., 1-may.
# 360                                      CH..., 1-may.
# 231                                     B..., 19-mart.
# 230                                     B..., 19-mart.
# ..                                                 ...
# 373  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 372  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 371  Shirin-shirin kulimsirab turgan inju tishlarig...
# 370  Shirin-shirin kulimsirab turgan inju tishlarig...
# 379  Farida, tog'larda bir o't o'sadi, otini bilmay...
#
#                                               text_spt  \
# id
# 362                                           Ch 1-may
# 361                                           Ch 1-may
# 360                                           Ch 1-may
# 231                                          B 19-mart
# 230                                          B 19-mart
# ..                                                 ...
# 373  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 372  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 371  Shirin-shirin kulimsirab turgan inju tishlarig...
# 370  Shirin-shirin kulimsirab turgan inju tishlarig...
# 379  Farida, tog'larda bir o't o'sadi, otini bilmay...
#
#                                         ref_normalized  \
# id
# 362                                      CH..., 1-may.
# 361                                      CH..., 1-may.
# 360                                      CH..., 1-may.
# 231                                     B..., 19-mart.
# 230                                     B..., 19-mart.
# ..                                                 ...
# 373  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 372  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...
# 371  Shirin-shirin kulimsirab turgan inju tishlarig...
# 370  Shirin-shirin kulimsirab turgan inju tishlarig...
# 379  Farida, tog'larda bir o't o'sadi, otini bilmay...
#
#                                         hyp_normalized  wer     cer  \
# id
# 362                                           Ch 1-may  1.0  0.4615
# 361                                           Ch 1-may  1.0  0.4615
# 360                                           Ch 1-may  1.0  0.4615
# 231                                          B 19-mart  1.0  0.3571
# 230                                          B 19-mart  1.0  0.3571
# ..                                                 ...  ...     ...
# 373  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...  0.0  0.0000
# 372  Yana bir qilmishi oshkor bo'lgan edi. Demak, o...  0.0  0.0000
# 371  Shirin-shirin kulimsirab turgan inju tishlarig...  0.0  0.0000
# 370  Shirin-shirin kulimsirab turgan inju tishlarig...  0.0  0.0000
# 379  Farida, tog'larda bir o't o'sadi, otini bilmay...  0.0  0.0000
#
#      sequence_similarity  ref_word_count  hyp_word_count
# id
# 362               0.6667               2               2
# 361               0.6667               2               2
# 360               0.6667               2               2
# 231               0.7826               2               2
# 230               0.7826               2               2
# ..                   ...             ...             ...
# 373               1.0000              25              25
# 372               1.0000              25              25
# 371               1.0000              21              21
# 370               1.0000              21              21
# 379               1.0000              17              17
#
# [830 rows x 13 columns]

# %%
mask = feruza_speech_df["wer"] > 0.0
total_duration_affected = feruza_speech_df[mask]["duration"].sum() / 3600
total_duration = feruza_speech_df["duration"].sum() / 3600

feruza_speech_df.loc[mask, "ref_normalized"] = feruza_speech_df.loc[mask, "hyp_normalized"]
feruza_speech_df.loc[mask, "wer"] = 0.0
feruza_speech_df.loc[mask, "cer"] = 0.0
feruza_speech_df.loc[mask, "sequence_similarity"] = 1.0
feruza_speech_df.loc[mask, "ref_word_count"] = feruza_speech_df.loc[mask, "hyp_word_count"]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
feruza_speech_df.to_csv("feruza_speech_modified_part2.csv", index_label="id")
# Out:
# Total duration affected: 2.23 hours (out of 3.22 hours)

# %%
common_voice_df = pd.read_csv("common_voice_part2.csv", index_col="id")
common_voice_df.drop(columns={"speaker_trust_score"}, inplace=True)
common_voice_df.rename(
    columns={"sentence": "text_original", "predicted_sentence": "text_spt", "client_id": "speaker_id"},
    inplace=True
)

# Rename dataset type: dev -> validation
common_voice_df["type"] = common_voice_df["type"].replace("dev", "validation")
common_voice_df["path"] = common_voice_df["path"].str.replace(r".mp3$", ".wav", regex=True)

# Reorder text_original column to be one before the last column
cols = list(common_voice_df.columns)
cols.remove("text_original")
cols.insert(10, "text_original")
cols.remove("text_spt")
cols.insert(11, "text_spt")
cols.remove("speaker_id")
cols.insert(1, "speaker_id")
common_voice_df = common_voice_df[cols]

common_voice_df = apply_similarity_metrics(common_voice_df)
common_voice_df
# Out:
#                               path  \
# id
# 7571  common_voice_uz_28892774.wav
# 6553  common_voice_uz_29492915.wav
# 6707  common_voice_uz_29659552.wav
# 5145  common_voice_uz_29771945.wav
# 6526  common_voice_uz_28894630.wav
# ...                            ...
# 4632  common_voice_uz_28828269.wav
# 4634  common_voice_uz_28903020.wav
# 1913  common_voice_uz_30657618.wav
# 4618  common_voice_uz_29116185.wav
# 4596  common_voice_uz_28924135.wav
#
#                                              speaker_id  \
# id
# 7571  633f4e362252d4c478e27f908b68480f89933e92839bb0...
# 6553  aa6ecc7fd43b0bd12a2ef4265a218102d3c964d4c19e96...
# 6707  c9ca42351a125d9d954efb587e6965622b120307845e4a...
# 5145  65701bd746d41eb89b41eeac8caeb46055c868dafda4d8...
# 6526  72f41c6b4733d93836e0def2d211362ac6db2632ea326a...
# ...                                                 ...
# 4632  bd299afdd61c7e10f6352a24b16206e2e97339a36777a3...
# 4634  cbe9f3a0053bef07470f5179a26f992986f75403738e79...
# 1913  793fe0ce43a754a201704b36515c39acc4c902366c6dde...
# 4618  8c6aad4b38297f2e3f1f1e6f10b7bb69af360c432a043c...
# 4596  cc7bdaa70930c795eda78822eea4fe1bf9a477ea75f3e0...
#
#                                             sentence_id  up_votes  down_votes  \
# id
# 7571  a5356ceefe726034a0742413320f4c76f853b887750144...         2           0
# 6553  2df183e98e1caf5e45b1d65b9c76b2d9d7e64e4f54e75d...         2           0
# 6707  4874e1acfcf4e5aa96de55672fc4dbcee42d1364523702...         2           0
# 5145  607d988fb82cb3827f5413756cdfad582e5f66145fe46a...         2           0
# 6526  b353ac590bcd763f95225d405a6b7451a571a53eff16b9...         2           0
# ...                                                 ...       ...         ...
# 4632  3634596e8202fc0729249ecb56d5f78fd635da7b704e5f...         2           0
# 4634  7e90a30314927ba70b5b4cc227a10c642f33c6fb2c70ec...         2           0
# 1913  0fed99a28f21ba7d1a4ed8d947163f51e2f04341fe9d5e...         0           0
# 4618  881a8775dd7344930fcbb16f8822b48258f03991421d0a...         2           0
# 4596  e7619784bc930f29c785830bb1993628e9587f32211a0f...         2           0
#
#            age           gender   type  duration  word_count  \
# id
# 7571  twenties   male_masculine  train     3.456           2
# 6553       NaN              NaN   test     3.420           2
# 6707     teens   male_masculine   test     3.708           2
# 5145       NaN              NaN   test     4.320           2
# 6526     teens  female_feminine  train     3.780           3
# ...        ...              ...    ...       ...         ...
# 4632     teens   male_masculine   test     5.148           5
# 4634       NaN              NaN   test     4.940           5
# 1913  twenties   male_masculine  train     6.050           8
# 4618       NaN              NaN   test     6.120           6
# 4596  twenties   male_masculine  train     7.668           7
#
#                                           text_original  \
# id
# 7571                           O'g'illarini uylantirdi.
# 6553                                    Ayniqsa, oyimni
# 6707                                O'rgatib oldingizmi
# 5145                                  Kelajagi, davomi.
# 6526                                 O'n yettinchi asr.
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                                text_spt  \
# id
# 7571                            o'g'illarini uylantirdi
# 6553                                    Ayniqsa oyimni.
# 6707                               o'rgatib oldingizmi?
# 5145                                    kelajagi davomi
# 6526                                             17-asr
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                          ref_normalized  \
# id
# 7571                           O'g'illarini uylantirdi.
# 6553                                    Ayniqsa, oyimni
# 6707                                O'rgatib oldingizmi
# 5145                                  Kelajagi, davomi.
# 6526                                 O'n yettinchi asr.
# ...                                                 ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.
# 4634                     Biz bir muddat yolg'iz qoldik.
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...
#
#                                          hyp_normalized  wer     cer  \
# id
# 7571                            o'g'illarini uylantirdi  1.0  0.0833
# 6553                                    Ayniqsa oyimni.  1.0  0.1333
# 6707                               o'rgatib oldingizmi?  1.0  0.1053
# 5145                                    kelajagi davomi  1.0  0.1765
# 6526                                             17-asr  1.0  0.8333
# ...                                                 ...  ...     ...
# 4632         Malika nihoyatda nazokat bilan gaplashadi.  0.0  0.0000
# 4634                     Biz bir muddat yolg'iz qoldik.  0.0  0.0000
# 1913  Zamonimiz qahramonining shafqatsiz taqdiri men...  0.0  0.0000
# 4618  Bu alohida fikr-mulohaza yuritishni talab qiladi.  0.0  0.0000
# 4596  Harakatlanayotgan poyezd elektrodvigateldan tu...  0.0  0.0000
#
#       sequence_similarity  ref_word_count  hyp_word_count
# id
# 7571               0.9362               2               2
# 6553               0.9333               2               2
# 6707               0.9231               2               2
# 5145               0.8750               2               2
# 6526               0.2500               3               1
# ...                   ...             ...             ...
# 4632               1.0000               5               5
# 4634               1.0000               5               5
# 1913               1.0000               8               8
# 4618               1.0000               6               6
# 4596               1.0000               7               7
#
# [7631 rows x 19 columns]

# %%
mask = common_voice_df["wer"] > 0.0
total_duration_affected = common_voice_df[mask]["duration"].sum() / 3600
total_duration = common_voice_df["duration"].sum() / 3600

common_voice_df.loc[mask, "ref_normalized"] = common_voice_df.loc[mask, "hyp_normalized"]
common_voice_df.loc[mask, "wer"] = 0.0
common_voice_df.loc[mask, "cer"] = 0.0
common_voice_df.loc[mask, "sequence_similarity"] = 1.0
common_voice_df.loc[mask, "ref_word_count"] = common_voice_df.loc[mask, "hyp_word_count"]

test_val_df = common_voice_df[common_voice_df["type"].isin(["test", "validation"])]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
test_val_df.to_csv("common_voice_modified_part2.csv", index_label="id")
# Out:
# Total duration affected: 7.83 hours (out of 13.70 hours)

# %%
uzbek_voice_df = pd.read_csv("uzbek_voice_part2.csv", index_col="id")

uzbek_voice_df.drop(columns={"net_votes"}, inplace=True)

uzbek_voice_df
# Out:
#                                  speaker_id                          path  \
# id
# 0      eecc8201-90e7-4fe9-9875-0d0e15246047                       123.wav
# 1      eecc8201-90e7-4fe9-9875-0d0e15246047                       124.wav
# 2      eecc8201-90e7-4fe9-9875-0d0e15246047                       129.wav
# 3      2473562c-3f2d-49a5-b780-7a1809db4f2e                       159.wav
# 4      f17a9f7e-eea8-4bd2-a4bc-c5586da0df3b                       164.wav
# ...                                     ...                           ...
# 60428  2f22150b-721c-4dc6-b2dd-ad02e453bceb  854864_augmented_pch_msk.wav
# 60429  2f22150b-721c-4dc6-b2dd-ad02e453bceb  854866_augmented_spd_nse.wav
# 60430  2f22150b-721c-4dc6-b2dd-ad02e453bceb  854866_augmented_pch_msk.wav
# 60431  2f22150b-721c-4dc6-b2dd-ad02e453bceb  854869_augmented_spd_nse.wav
# 60432  2f22150b-721c-4dc6-b2dd-ad02e453bceb  854869_augmented_pch_msk.wav
#
#          accent_region  up_votes  down_votes  reported_count    age  \
# id
# 0      Toshkent shahri         5           0               0  50-59
# 1      Toshkent shahri         4           0               0  50-59
# 2      Toshkent shahri         5           0               0  50-59
# 3             Namangan         5           0               0  25-34
# 4      Toshkent shahri         5           0               0  18-24
# ...                ...       ...         ...             ...    ...
# 60428           Xorazm         0           0               0  18-24
# 60429           Xorazm         0           0               0  18-24
# 60430           Xorazm         0           0               0  18-24
# 60431           Xorazm         0           0               0  18-24
# 60432           Xorazm         0           0               0  18-24
#
#                 gender  duration  word_count  \
# id
# 0      female_feminine    3.0960           3
# 1      female_feminine    3.8520           4
# 2      female_feminine    3.9960           3
# 3      female_feminine    3.3480           3
# 4      female_feminine    3.0600           3
# ...                ...       ...         ...
# 60428  female_feminine    5.6160           7
# 60429  female_feminine    7.4413           7
# 60430  female_feminine    7.2360           7
# 60431  female_feminine    6.6981           9
# 60432  female_feminine    6.6600           9
#
#                                            text_original  \
# id
# 0                              Haqiqiy fransuzcha ekler.
# 1               O‘zbekistonlik mashhurlarning bolaligi .
# 2                      “O‘qituvchilardan ko‘nglim qoldi.
# 3                            Misol keltiradigan bo‘lsam.
# 4                            Futbolning yuqori darajasi.
# ...                                                  ...
# 60428      • Qiyin ishni oldinga, osonini keyinga sur.\r
# 60429  Bo‘lmaydi! Qanday bo‘lsa, shundayligicha el qi...
# 60430  Bo‘lmaydi! Qanday bo‘lsa, shundayligicha el qi...
# 60431  Tolibon ikki nafar askar va yosh bolani otib o...
# 60432  Tolibon ikki nafar askar va yosh bolani otib o...
#
#                                                 text_spt  \
# id
# 0                               haqiqiy fransuzcha ekler
# 1                 O'zbekistonlik mashhurlarning bolaligi
# 2                       O'qituvchilardan ko'nglim qoldi.
# 3                             misol keltiradigan bo'lsam
# 4                             futbolning yuqori darajasi
# ...                                                  ...
# 60428          Qiyin ishni oldinga, osonini keyinga sur.
# 60429  Bo'lmaydi, qanday bo'lsa shundayligicha el qil...
# 60430  Bo'lmaydi, qanday bo'lsa shundayligicha el qil...
# 60431  Tolibon ikki nafar askar va yosh bolani otib o...
# 60432  Tolibon ikki nafar askar va yosh bolani otib o...
#
#                                           ref_normalized  \
# id
# 0                               haqiqiy fransuzcha ekler
# 1                 o'zbekistonlik mashhurlarning bolaligi
# 2                        o'qituvchilardan ko'nglim qoldi
# 3                             misol keltiradigan bo'lsam
# 4                             futbolning yuqori darajasi
# ...                                                  ...
# 60428            qiyin ishni oldinga osonini keyinga sur
# 60429  bo'lmaydi qanday bo'lsa shundayligicha el qili...
# 60430  bo'lmaydi qanday bo'lsa shundayligicha el qili...
# 60431  tolibon ikki nafar askar va yosh bolani otib o...
# 60432  tolibon ikki nafar askar va yosh bolani otib o...
#
#                                           hyp_normalized  wer  cer  \
# id
# 0                               haqiqiy fransuzcha ekler  0.0  0.0
# 1                 o'zbekistonlik mashhurlarning bolaligi  0.0  0.0
# 2                        o'qituvchilardan ko'nglim qoldi  0.0  0.0
# 3                             misol keltiradigan bo'lsam  0.0  0.0
# 4                             futbolning yuqori darajasi  0.0  0.0
# ...                                                  ...  ...  ...
# 60428            qiyin ishni oldinga osonini keyinga sur  0.0  0.0
# 60429  bo'lmaydi qanday bo'lsa shundayligicha el qili...  0.0  0.0
# 60430  bo'lmaydi qanday bo'lsa shundayligicha el qili...  0.0  0.0
# 60431  tolibon ikki nafar askar va yosh bolani otib o...  0.0  0.0
# 60432  tolibon ikki nafar askar va yosh bolani otib o...  0.0  0.0
#
#        sequence_similarity  ref_word_count  hyp_word_count   type
# id
# 0                      1.0               3               3  train
# 1                      1.0               3               3  train
# 2                      1.0               3               3  train
# 3                      1.0               3               3  train
# 4                      1.0               3               3  train
# ...                    ...             ...             ...    ...
# 60428                  1.0               6               6  train
# 60429                  1.0               7               7  train
# 60430                  1.0               7               7  train
# 60431                  1.0               9               9  train
# 60432                  1.0               9               9  train
#
# [60431 rows x 20 columns]

# %%
# Example: O‘ylashimcha, hammasi yaxshilikka”, deydi Jaloliddinov.
trailing_quote_mask = uzbek_voice_df["text_spt"].str.contains(r"(^[^“]*)”([^“]*$)", regex=True)
matched = uzbek_voice_df[trailing_quote_mask][["path", "text_original", "text_spt", "ref_normalized"]]

uzbek_voice_df["text_spt"] = uzbek_voice_df["text_spt"].str.replace(
    r"(^[^“]*)”([^“]*$)",
    r"\1\2",
    regex=True
)
uzbek_voice_df.loc[trailing_quote_mask, "text_original"] = uzbek_voice_df.loc[
    trailing_quote_mask, "text_original"].str.replace(
    r"(^[^“]*)”([^“]*$)",
    r"\1\2",
    regex=True
)

matched
# Out:
# /tmp/ipykernel_904369/1253041954.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   trailing_quote_mask = uzbek_voice_df["text_spt"].str.contains(r"(^[^“]*)”([^“]*$)", regex=True)
#                                path  \
# id
# 46333                     52636.wav
# 46404                     60154.wav
# 46435                     67148.wav
# 47064                    107424.wav
# 47303                    119746.wav
# 47527                    135565.wav
# 48151                    160296.wav
# 48184                    162378.wav
# 48374                    169453.wav
# 48459                    171012.wav
# 48618                    172542.wav
# 48712                    174183.wav
# 48910                    179640.wav
# 49682                    197480.wav
# 50142                    319566.wav
# 50344                    337360.wav
# 50465                    343388.wav
# 50968                    390109.wav
# 51261                    437644.wav
# 51794                    462389.wav
# 52002                    471347.wav
# 55713  124817_augmented_spd_nse.wav
# 55714  124817_augmented_pch_msk.wav
# 56103  312767_augmented_spd_nse.wav
# 56104  312767_augmented_pch_msk.wav
# 57009  352098_augmented_spd_nse.wav
# 57010  352098_augmented_pch_msk.wav
# 58583  431923_augmented_spd_nse.wav
# 58584  431923_augmented_pch_msk.wav
#
#                                            text_original  \
# id
# 46333  Istalgan turdagi zo‘ravonlikka”, deydi Infantino.
# 46404        Seni ko‘rganimdan xursandman”, deydi Nikol.
# 46435  Baqirdim, chaqirdim...” Uyog‘iga faqat yig‘lagan.
# 47064  To‘qqiz kishi jabrlandi”, deydi agentlik suhba...
# 47303      Munisa!”, deb baqirayotganini ko‘rish mumkin.
# 47527  Uni konsertgacha premyera qilamiz”, qo‘shimcha...
# 48151  Aslida musobaqani yomon o‘tkazmadik”, dedi Lyu...
# 48184  O‘qituvchi jamiyatning poydevori”, deya qo‘shi...
# 48374  Bu xuddi Yevropa ittifoqiga o‘xshagan birlashu...
# 48459  Shundan so‘ng u shifoxonaga yetkazildi”, deyil...
# 48618  Siz bu yurtga buyuklikni qaytarasiz’”, degandi...
# 48712  Men shunchaki Milluollni yaxshi ko‘raman…” ded...
# 48910  Aybim, haqiqatni yozganimmi?”, deydi Zafar Jo‘...
# 49682  Ko‘rib turganingizdek shu bois mashinalar navb...
# 50142  Keksayish turli tajribalar orttirish ham demak...
# 50344  Hammaga katta rahmat”, – deydi fuqaro Muzayamx...
# 50465  O‘zbekistonning noyob o‘simliklari” pochta mar...
# 50968  Ko‘rinib turibdiki, ularning xavfsizligi bizni...
# 51261  Baxmal olmasi ham respublika bo‘ylab taniqlidi...
# 51794  Huquqni muhofaza qilish organlari xodimlari qa...
# 52002  Obama esa nega olganini ham bilmaydi”, deydi T...
# 55713  Butun O‘zbekistondan kechirim so‘rayman”, deyd...
# 55714  Butun O‘zbekistondan kechirim so‘rayman”, deyd...
# 56103   U endi xuddi ichishni tashlagandek ko‘rinyapti”.
# 56104   U endi xuddi ichishni tashlagandek ko‘rinyapti”.
# 57009  Kokain Kolumbiyadan kelirilgan bananlar kontey...
# 57010  Kokain Kolumbiyadan kelirilgan bananlar kontey...
# 58583  Shu sabab uni heshtegga ololmadik”, deya vaziy...
# 58584  Shu sabab uni heshtegga ololmadik”, deya vaziy...
#
#                                                 text_spt  \
# id
# 46333  Istalgan turdagi zo‘ravonlikka”, deydi Infantino.
# 46404        Seni ko‘rganimdan xursandman”, deydi Nikol.
# 46435  Baqirdim, chaqirdim...” Uyog‘iga faqat yig‘lagan.
# 47064  To‘qqiz kishi jabrlandi”, deydi agentlik suhba...
# 47303      Munisa!”, deb baqirayotganini ko‘rish mumkin.
# 47527  Uni konsertgacha premyera qilamiz”, qo‘shimcha...
# 48151  Aslida musobaqani yomon o‘tkazmadik”, dedi Lyu...
# 48184  O‘qituvchi jamiyatning poydevori”, deya qo‘shi...
# 48374  Bu xuddi Yevropa ittifoqiga o‘xshagan birlashu...
# 48459  Shundan so‘ng u shifoxonaga yetkazildi”, deyil...
# 48618  Siz bu yurtga buyuklikni qaytarasiz’”, degandi...
# 48712  Men shunchaki Milluollni yaxshi ko‘raman…” ded...
# 48910  Aybim, haqiqatni yozganimmi?”, deydi Zafar Jo‘...
# 49682  Ko‘rib turganingizdek shu bois mashinalar navb...
# 50142  Keksayish turli tajribalar orttirish ham demak...
# 50344  Hammaga katta rahmat”, – deydi fuqaro Muzayamx...
# 50465  O‘zbekistonning noyob o‘simliklari” pochta mar...
# 50968  Ko‘rinib turibdiki, ularning xavfsizligi bizni...
# 51261  Baxmal olmasi ham respublika bo‘ylab taniqlidi...
# 51794  Huquqni muhofaza qilish organlari xodimlari qa...
# 52002  Obama esa nega olganini ham bilmaydi”, deydi T...
# 55713  Butun O‘zbekistondan kechirim so‘rayman”, deyd...
# 55714  Butun O‘zbekistondan kechirim so‘rayman”, deyd...
# 56103   U endi xuddi ichishni tashlagandek ko‘rinyapti”.
# 56104   U endi xuddi ichishni tashlagandek ko‘rinyapti”.
# 57009  Kokain Kolumbiyadan kelirilgan bananlar kontey...
# 57010  Kokain Kolumbiyadan kelirilgan bananlar kontey...
# 58583  Shu sabab uni heshtegga ololmadik”, deya vaziy...
# 58584  Shu sabab uni heshtegga ololmadik”, deya vaziy...
#
#                                           ref_normalized
# id
# 46333     istalgan turdagi zo'ravonlikka deydi infantino
# 46404           seni ko'rganimdan xursandman deydi nikol
# 46435        baqirdim chaqirdim uyog'iga faqat yig'lagan
# 47064  to'qqiz kishi jabrlandi deydi agentlik suhbatd...
# 47303          munisa deb baqirayotganini ko'rish mumkin
# 47527  uni konsertgacha premyera qilamiz qo'shimcha q...
# 48151  aslida musobaqani yomon o'tkazmadik dedi lyubi...
# 48184  o'qituvchi jamiyatning poydevori deya qo'shimc...
# 48374  bu xuddi yevropa ittifoqiga o'xshagan birlashu...
# 48459  shundan so'ng u shifoxonaga yetkazildi deyilad...
# 48618  siz bu yurtga buyuklikni qaytarasiz' degandi k...
# 48712  men shunchaki milluollni yaxshi ko'raman dedi ...
# 48910    aybim haqiqatni yozganimmi deydi zafar jo'rayev
# 49682  ko'rib turganingizdek shu bois mashinalar navb...
# 50142  keksayish turli tajribalar orttirish ham demakdir
# 50344  hammaga katta rahmat deydi fuqaro muzayamxon f...
# 50465  o'zbekistonning noyob o'simliklari pochta mark...
# 50968  ko'rinib turibdiki ularning xavfsizligi biznin...
# 51261  baxmal olmasi ham respublika bo'ylab taniqlidi...
# 51794  huquqni muhofaza qilish organlari xodimlari qa...
# 52002  obama esa nega olganini ham bilmaydi deydi tra...
# 55713  butun o'zbekistondan kechirim so'rayman deydi ...
# 55714  butun o'zbekistondan kechirim so'rayman deydi ...
# 56103     u endi xuddi ichishni tashlagandek ko'rinyapti
# 56104     u endi xuddi ichishni tashlagandek ko'rinyapti
# 57009  kokain kolumbiyadan kelirilgan bananlar kontey...
# 57010  kokain kolumbiyadan kelirilgan bananlar kontey...
# 58583  shu sabab uni heshtegga ololmadik deya vaziyat...
# 58584  shu sabab uni heshtegga ololmadik deya vaziyat...

# %%
# Examples: 8 677 960, 971 483, 1 483
only_numbers_mask = uzbek_voice_df["text_spt"].str.contains(r"^(\d+(?: \d{3})*)$", regex=True)
matched = uzbek_voice_df[only_numbers_mask][["path", "text_original", "text_spt", "ref_normalized"]]

uzbek_voice_df.loc[only_numbers_mask, "text_spt"] = uzbek_voice_df.loc[only_numbers_mask, "text_original"]

uzbek_voice_df.to_csv("uzbek_voice_modified_part2.csv", index_label="id")
matched
# Out:
# /tmp/ipykernel_904369/4023398073.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   only_numbers_mask = uzbek_voice_df["text_spt"].str.contains(r"^(\d+(?: \d{3})*)$", regex=True)
#              path text_original   text_spt  \
# id
# 45719  855105.wav        18 097      18097
# 45721  855293.wav        12 054      12054
# 45722  855298.wav        14 004      14004
# 45723  855307.wav        85 005      85005
# 45724  855310.wav        12 227     12 227
# ...           ...           ...        ...
# 55168  861642.wav       826 482     826482
# 55169  861648.wav        71 065      71065
# 55170  861652.wav       944 507     944507
# 55171  861653.wav     3 290 587  3 290 587
# 55172  861656.wav     2 341 556  2 341 556
#
#                                           ref_normalized
# id
# 45719                      o'n sakkiz ming to'qson yetti
# 45721                          o'n ikki ming ellik to'rt
# 45722                               o'n to'rt ming to'rt
# 45723                              sakson besh ming besh
# 45724               o'n ikki ming ikki yuz yigirma yetti
# ...                                                  ...
# 55168  sakkiz yuz yigirma olti ming to'rt yuz sakson ...
# 55169                      yetmish bir ming oltmish besh
# 55170         to'qqiz yuz qirq to'rt ming besh yuz yetti
# 55171  uch million ikki yuz to'qson ming besh yuz sak...
# 55172  ikki million uch yuz qirq bir ming besh yuz el...
#
# [556 rows x 4 columns]

# %%
uzbek_voice_df = apply_similarity_metrics(uzbek_voice_df)

case_not_aligned_mask = uzbek_voice_df["wer"] > 0.0
uzbek_voice_df[case_not_aligned_mask][["text_original", "text_spt", "ref_normalized", "hyp_normalized"]]
# Out:
#                                            text_original  \
# id
# 183                 “Barkamol avlod2014” musobaqalarida.
# 518                            Ishsizlik darajasi: 5.0%.
# 467                   Hammasi “Niva”, “UAZ” mashinalari.
# 390                      “Shunchaki do‘stlar”, 2005-yil.
# 11571  Darvozabonlar Himoyachilar Yarim himoyachilar ...
# ...                                                  ...
# 43737  Sovet ittifoqi davrida senzura bor edi, lekin ...
# 44525  Maktab avtobusi oʻquvchilarni tushirish uchun ...
# 44708  Samolyotlarning katta qismi oq rangda boʻladi ...
# 44703  Samolyotlarning katta qismi oq rangda boʻladi ...
# 54239  Insonparvarlik yukini mamlakatga yuborish xara...
#
#                                                 text_spt  \
# id
# 183                   Barkamol avlod 2014 musobaqalarida
# 518                                ishsizlik darajasi 5%
# 467                         hammasi Niva Uaz mashinalari
# 390                          Shunchaki do'stlar 2005-yil
# 11571  darvozabonlar, himoyachilar, yarim himoyachila...
# ...                                                  ...
# 43737  Sovet Ittifoqi davrida senzura bor edi, lekin ...
# 44525  Maktab avtobusi o'quvchilarni tushirish uchun ...
# 44708  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 44703  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 54239  Insonparvarlik yukini mamlakatga yuborish xara...
#
#                                           ref_normalized  \
# id
# 183                 "Barkamol avlod2014" musobaqalarida.
# 518                            Ishsizlik darajasi: 5.0%.
# 467                   Hammasi "Niva", "UAZ" mashinalari.
# 390                      "Shunchaki do'stlar", 2005-yil.
# 11571  Darvozabonlar Himoyachilar Yarim himoyachilar ...
# ...                                                  ...
# 43737  Sovet ittifoqi davrida senzura bor edi, lekin ...
# 44525  Maktab avtobusi o'quvchilarni tushirish uchun ...
# 44708  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 44703  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 54239  Insonparvarlik yukini mamlakatga yuborish xara...
#
#                                           hyp_normalized
# id
# 183                   Barkamol avlod 2014 musobaqalarida
# 518                                ishsizlik darajasi 5%
# 467                         hammasi Niva Uaz mashinalari
# 390                          Shunchaki do'stlar 2005-yil
# 11571  darvozabonlar, himoyachilar, yarim himoyachila...
# ...                                                  ...
# 43737  Sovet Ittifoqi davrida senzura bor edi, lekin ...
# 44525  Maktab avtobusi o'quvchilarni tushirish uchun ...
# 44708  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 44703  Samolyotlarning katta qismi oq rangda bo'ladi ...
# 54239  Insonparvarlik yukini mamlakatga yuborish xara...
#
# [18064 rows x 4 columns]

# %%
# Reorder type column
cols = list(uzbek_voice_df.columns)
cols.remove("type")
cols.insert(2, "type")
uzbek_voice_df = uzbek_voice_df[cols]

uzbek_voice_df = uzbek_voice_df[~uzbek_voice_df.duplicated(subset=["path", "speaker_id"], keep="first")]

mask = uzbek_voice_df["wer"] > 0.0
total_duration_affected = uzbek_voice_df[mask]["duration"].sum() / 3600
total_duration = uzbek_voice_df["duration"].sum() / 3600

uzbek_voice_df.loc[mask, "ref_normalized"] = uzbek_voice_df.loc[mask, "hyp_normalized"]
uzbek_voice_df.loc[mask, "wer"] = 0.0
uzbek_voice_df.loc[mask, "cer"] = 0.0
uzbek_voice_df.loc[mask, "sequence_similarity"] = 1.0
uzbek_voice_df.loc[mask, "ref_word_count"] = uzbek_voice_df.loc[mask, "hyp_word_count"]

print(f"Total duration affected: {total_duration_affected:.2f} hours (out of {total_duration:.2f} hours)")
uzbek_voice_df.to_csv("uzbek_voice_modified_part2.csv", index_label="id")
# Out:
# Total duration affected: 27.43 hours (out of 89.63 hours)

# %%
news_df = pd.read_csv("news_dataset_part2.csv", index_col="id")

# Swap places of text_spt (Google STT generated as reference) -> text_original (Gemini 2.5 Pro generated as hypothesis)
# Because apply_similarity_metrics method assumes text_original as reference
news_df.rename(
    columns={"text_spt": "text_original", "text_original": "text_spt"},
    inplace=True
)

news_df = apply_similarity_metrics(news_df)
news_df
# Out:
#                                  path  duration   type  \
# id
# 331                    00011451_0.wav    4.4000  train
# 9626                   00010266_0.wav   11.9700  train
# 290                    00011161_0.wav    7.5300  train
# 9660                   00010307_0.wav    7.0300  train
# 0                      00004289_0.wav   10.6700  train
# ...                               ...       ...    ...
# 11049  00008539_augmented_spd_nse.wav    4.8536  train
# 11050  00008539_augmented_pch_msk.wav    5.2321  train
# 11057  00008614_augmented_spd_nse.wav    8.1944  train
# 11058  00008614_augmented_pch_msk.wav    7.8987  train
# 5729                   00003256_1.wav    7.2600  train
#
#                                            text_original  \
# id
# 331                                        19065 koykaga
# 9626   rezolyutiv qismini e'lon qilaman. O'zbekiston ...
# 290    Даже если этого постановления нету. 16-iyulda ...
# 9660   43 812 220 so'm Mirzakalonov Otabek Erkinjon o...
# 0      128 million 177 500 so'm pul hamda 2016-yil 24...
# ...                                                  ...
# 11049          moddasida jinoiy javobgarlik belgilangan.
# 11050          moddasida jinoiy javobgarlik belgilangan.
# 11057  kasallangan fuqarolarimizning oila a'zolariga ...
# 11058  kasallangan fuqarolarimizning oila a'zolariga ...
# 5729   davlat qonunni samarali amalga oshirishi va da...
#
#                                                 text_spt  \
# id
# 331                o'n to'qqiz ming oltmish besh koykaga
# 9626   men rezolyutiv qismini e'lon qilaman. O'zbekis...
# 290    Daje yesli etogo postanovleniya netu, o'n olti...
# 9660   qirq uch million sakkiz yuz o'n ikki ming ikki...
# 0      bir yuz yigirma sakkiz million, bir yuz yetmis...
# ...                                                  ...
# 11049          moddasida jinoiy javobgarlik belgilangan.
# 11050          moddasida jinoiy javobgarlik belgilangan.
# 11057  kasallangan fuqarolarimizning oila aʼzolariga ...
# 11058  kasallangan fuqarolarimizning oila aʼzolariga ...
# 5729   davlat qonunni samarali amalga oshirishi va da...
#
#                                           ref_normalized  \
# id
# 331                                        19065 koykaga
# 9626   rezolyutiv qismini e'lon qilaman. O'zbekiston ...
# 290    Даже если этого постановления нету. 16-iyulda ...
# 9660   43 812 220 so'm Mirzakalonov Otabek Erkinjon o...
# 0      128 million 177 500 so'm pul hamda 2016-yil 24...
# ...                                                  ...
# 11049          moddasida jinoiy javobgarlik belgilangan.
# 11050          moddasida jinoiy javobgarlik belgilangan.
# 11057  kasallangan fuqarolarimizning oila a'zolariga ...
# 11058  kasallangan fuqarolarimizning oila a'zolariga ...
# 5729   davlat qonunni samarali amalga oshirishi va da...
#
#                                           hyp_normalized     wer     cer  \
# id
# 331                o'n to'qqiz ming oltmish besh koykaga  2.5000  2.2308
# 9626   men rezolyutiv qismini e'lon qilaman. O'zbekis...  1.8824  1.3047
# 290    Daje yesli etogo postanovleniya netu, o'n olti...  1.6250  1.0896
# 9660   qirq uch million sakkiz yuz o'n ikki ming ikki...  1.5000  1.0556
# 0      bir yuz yigirma sakkiz million, bir yuz yetmis...  1.3333  1.0364
# ...                                                  ...     ...     ...
# 11049          moddasida jinoiy javobgarlik belgilangan.  0.0000  0.0000
# 11050          moddasida jinoiy javobgarlik belgilangan.  0.0000  0.0000
# 11057  kasallangan fuqarolarimizning oila a'zolariga ...  0.0000  0.0000
# 11058  kasallangan fuqarolarimizning oila a'zolariga ...  0.0000  0.0000
# 5729   davlat qonunni samarali amalga oshirishi va da...  0.0000  0.0000
#
#        sequence_similarity  ref_word_count  hyp_word_count
# id
# 331                 0.3200               2               6
# 9626                0.4511              17              40
# 290                 0.3432               8              14
# 9660                0.5860               8              16
# 0                   0.5823               9              17
# ...                    ...             ...             ...
# 11049               1.0000               4               4
# 11050               1.0000               4               4
# 11057               1.0000               9               9
# 11058               1.0000               9               9
# 5729                1.0000              11              11
#
# [13133 rows x 12 columns]

# %%
mask = news_df["wer"] > 0.0
not_aligned_duration = news_df[mask]["duration"].sum() / 3600
total_duration = news_df["duration"].sum() / 3600

print("Nothing changed here.")
print(f"Not aligned total duration: {not_aligned_duration:.2f} hours (out of {total_duration:.2f} hours)")
news_df.to_csv("news_dataset_modified_part2.csv", index_label="id")
# Out:
# Nothing changed here.
# Not aligned total duration: 47.42 hours (out of 54.66 hours)

# %%
it_df = pd.read_csv("it_dataset_part2.csv", index_col="id")

# Swap places of text_spt (Google STT generated as reference) -> text_original (Gemini 2.5 Pro generated as hypothesis)
# Because apply_similarity_metrics method assumes text_original as reference
it_df.rename(
    columns={"text_spt": "text_original", "text_original": "text_spt"},
    inplace=True
)

it_df = apply_similarity_metrics(it_df)
it_df = it_df[[
    "path", "duration", "type", "text_original", "text_spt", "ref_normalized", "hyp_normalized", "wer", "cer",
    "sequence_similarity", "ref_word_count", "hyp_word_count"
]]

it_df
# Out:
#                              path  duration   type  \
# id
# 970   09757_augmented_spd_nse.wav    7.6177  train
# 971   09757_augmented_pch_msk.wav    7.3047  train
# 1466  16134_augmented_spd_nse.wav   17.7436  train
# 1467  16134_augmented_pch_msk.wav   17.9467  train
# 2270                    12139.wav   14.2240   test
# ...                           ...       ...    ...
# 1733  18258_augmented_pch_msk.wav    7.6300  train
# 1732  18258_augmented_spd_nse.wav    7.4534  train
# 384   04354_augmented_spd_nse.wav    4.3671  train
# 649   05920_augmented_pch_msk.wav    7.2000  train
# 886   08856_augmented_spd_nse.wav   14.2564  train
#
#                                           text_original  \
# id
# 970   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 971   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 1466  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# 1467  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# 2270  yaxshi savol, meni holatimda bu narsa vaziyatn...
# ...                                                 ...
# 1733  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 1732  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 384                                    Keyingi savolim.
# 649   XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 886   Mohirdev platformasida Data Science va sun'iy ...
#
#                                                text_spt  \
# id
# 970   Assalomu alaykum. Ismim Botirjon, familiyam Ha...
# 971   Assalomu alaykum. Ismim Botirjon, familiyam Ha...
# 1466  bu start ikki ming yigirma ikkinchi yilgacha h...
# 1467  bu start ikki ming yigirma ikkinchi yilgacha h...
# 2270  Yaxshi savol. Mani holatimda bu narsa, aa, vaz...
# ...                                                 ...
# 1733  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 1732  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 384                                    Keyingi savolim.
# 649   XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 886   Mohirdev platformasida Data Science va sun'iy ...
#
#                                          ref_normalized  \
# id
# 970   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 971   Assalomu alaykum, ismim Botirjon, familiyam Ha...
# 1466  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# 1467  Bu start 2022-yilgacha start qilamiz, xudo xoh...
# 2270  yaxshi savol, meni holatimda bu narsa vaziyatn...
# ...                                                 ...
# 1733  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 1732  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 384                                    Keyingi savolim.
# 649   XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 886   Mohirdev platformasida Data Science va sun'iy ...
#
#                                          hyp_normalized     wer     cer  \
# id
# 970   Assalomu alaykum. Ismim Botirjon, familiyam Ha...  0.7500  0.0735
# 971   Assalomu alaykum. Ismim Botirjon, familiyam Ha...  0.7500  0.0735
# 1466  bu start ikki ming yigirma ikkinchi yilgacha h...  0.7000  0.3009
# 1467  bu start ikki ming yigirma ikkinchi yilgacha h...  0.7000  0.3009
# 2270  Yaxshi savol. Mani holatimda bu narsa, aa, vaz...  0.5882  0.1190
# ...                                                 ...     ...     ...
# 1733  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...  0.0000  0.0000
# 1732  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...  0.0000  0.0000
# 384                                    Keyingi savolim.  0.0000  0.0000
# 649   XS qismida esa mana pastroqqa tushamiz. Bu quy...  0.0000  0.0000
# 886   Mohirdev platformasida Data Science va sun'iy ...  0.0000  0.0000
#
#       sequence_similarity  ref_word_count  hyp_word_count
# id
# 970                0.9343               8               9
# 971                0.9343               8               9
# 1466               0.1647              30              39
# 1467               0.1647              30              39
# 2270               0.9147              17              18
# ...                   ...             ...             ...
# 1733               1.0000              12              12
# 1732               1.0000              12              12
# 384                1.0000               2               2
# 649                1.0000              14              14
# 886                1.0000              32              32
#
# [2372 rows x 12 columns]

# %%
mask = it_df["wer"] > 0.0
not_aligned_duration = it_df[mask]["duration"].sum() / 3600
total_duration = it_df["duration"].sum() / 3600

print("Nothing changed here.")
print(f"Not aligned total duration: {not_aligned_duration:.2f} hours (out of {total_duration:.2f} hours)")
it_df.to_csv("it_dataset_modified_part2.csv", index_label="id")
# Out:
# Nothing changed here.
# Not aligned total duration: 8.71 hours (out of 9.41 hours)

# %% [markdown]
# ## Combine All Case Sensitive Datasets

# %%
feruza_speech_df = pd.read_csv("feruza_speech_modified_part2.csv", index_col="id")
common_voice_df = pd.read_csv("common_voice_modified_part2.csv", index_col="id")
uzbek_voice_df = pd.read_csv("uzbek_voice_modified_part2.csv", index_col="id")
news_df = pd.read_csv("news_dataset_modified_part2.csv", index_col="id")
it_df = pd.read_csv("it_dataset_modified_part2.csv", index_col="id")

feruza_speech_df["dataset"] = "feruza_speech"
common_voice_df["dataset"] = "common_voice"
uzbek_voice_df["dataset"] = "uzbek_voice"
news_df["dataset"] = "news"
it_df["dataset"] = "it"

combined_case_sensitive_df = pd.concat(
    [feruza_speech_df, common_voice_df, uzbek_voice_df, news_df, it_df],
    axis=0,
    ignore_index=True
)
# Reorder dataset column
cols = list(combined_case_sensitive_df.columns)
cols.remove("dataset")
cols.insert(2, "dataset")
cols.remove("word_count")
cols.insert(-1, "word_count")
combined_case_sensitive_df = combined_case_sensitive_df[cols]

combined_case_sensitive_df.to_csv("combined__case_sensitive_part2.csv", index_label="id")
combined_case_sensitive_df
# Out:
#                                path   type        dataset  duration  \
# 0      029-92_augmented_pch_msk.wav  train  feruza_speech    5.5001
# 1      029-92_augmented_spd_nse.wav  train  feruza_speech    6.9566
# 2      029-92_augmented_spd_pch.wav  train  feruza_speech    4.4474
# 3      026-01_augmented_nse_msk.wav  train  feruza_speech    3.3800
# 4      026-01_augmented_pch_msk.wav  train  feruza_speech    3.3800
# ...                             ...    ...            ...       ...
# 79263   18258_augmented_pch_msk.wav  train             it    7.6300
# 79264   18258_augmented_spd_nse.wav  train             it    7.4534
# 79265   04354_augmented_spd_nse.wav  train             it    4.3671
# 79266   05920_augmented_pch_msk.wav  train             it    7.2000
# 79267   08856_augmented_spd_nse.wav  train             it   14.2564
#
#                                            text_original  \
# 0                                          CH..., 1-may.
# 1                                          CH..., 1-may.
# 2                                          CH..., 1-may.
# 3                                         B..., 19-mart.
# 4                                         B..., 19-mart.
# ...                                                  ...
# 79263  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79264  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79265                                   Keyingi savolim.
# 79266  XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 79267  Mohirdev platformasida Data Science va sun'iy ...
#
#                                                 text_spt  \
# 0                                               Ch 1-may
# 1                                               Ch 1-may
# 2                                               Ch 1-may
# 3                                              B 19-mart
# 4                                              B 19-mart
# ...                                                  ...
# 79263  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79264  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79265                                   Keyingi savolim.
# 79266  XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 79267  Mohirdev platformasida Data Science va sun'iy ...
#
#                                           ref_normalized  \
# 0                                               Ch 1-may
# 1                                               Ch 1-may
# 2                                               Ch 1-may
# 3                                              B 19-mart
# 4                                              B 19-mart
# ...                                                  ...
# 79263  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79264  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...
# 79265                                   Keyingi savolim.
# 79266  XS qismida esa mana pastroqqa tushamiz. Bu quy...
# 79267  Mohirdev platformasida Data Science va sun'iy ...
#
#                                           hyp_normalized  wer  cer  ...  \
# 0                                               Ch 1-may  0.0  0.0  ...
# 1                                               Ch 1-may  0.0  0.0  ...
# 2                                               Ch 1-may  0.0  0.0  ...
# 3                                              B 19-mart  0.0  0.0  ...
# 4                                              B 19-mart  0.0  0.0  ...
# ...                                                  ...  ...  ...  ...
# 79263  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...  0.0  0.0  ...
# 79264  12-noyabrdan darslarimiz boshlangan bo'lsa, ro...  0.0  0.0  ...
# 79265                                   Keyingi savolim.  0.0  0.0  ...
# 79266  XS qismida esa mana pastroqqa tushamiz. Bu quy...  0.0  0.0  ...
# 79267  Mohirdev platformasida Data Science va sun'iy ...  0.0  0.0  ...
#
#        hyp_word_count  speaker_id  sentence_id up_votes down_votes  age  \
# 0                   2         NaN          NaN      NaN        NaN  NaN
# 1                   2         NaN          NaN      NaN        NaN  NaN
# 2                   2         NaN          NaN      NaN        NaN  NaN
# 3                   2         NaN          NaN      NaN        NaN  NaN
# 4                   2         NaN          NaN      NaN        NaN  NaN
# ...               ...         ...          ...      ...        ...  ...
# 79263              12         NaN          NaN      NaN        NaN  NaN
# 79264              12         NaN          NaN      NaN        NaN  NaN
# 79265               2         NaN          NaN      NaN        NaN  NaN
# 79266              14         NaN          NaN      NaN        NaN  NaN
# 79267              32         NaN          NaN      NaN        NaN  NaN
#
#        gender accent_region word_count reported_count
# 0         NaN           NaN        3.0            NaN
# 1         NaN           NaN        3.0            NaN
# 2         NaN           NaN        3.0            NaN
# 3         NaN           NaN        3.0            NaN
# 4         NaN           NaN        3.0            NaN
# ...       ...           ...        ...            ...
# 79263     NaN           NaN        NaN            NaN
# 79264     NaN           NaN        NaN            NaN
# 79265     NaN           NaN        NaN            NaN
# 79266     NaN           NaN        NaN            NaN
# 79267     NaN           NaN        NaN            NaN
#
# [79268 rows x 22 columns]

# %%
combined_case_sensitive_df.describe(include="all")
# Out:
#                   path   type      dataset      duration text_original  \
# count            79268  79268        79268  79268.000000         79254
# unique           79262      3            5           NaN         67855
# top     00004136_0.wav  train  uzbek_voice           NaN      [musiqa]
# freq                 2  66545        60431           NaN           280
# mean               NaN    NaN          NaN      7.311933           NaN
# std                NaN    NaN          NaN      5.065177           NaN
# min                NaN    NaN          NaN      2.310800           NaN
# 25%                NaN    NaN          NaN      5.040000           NaN
# 50%                NaN    NaN          NaN      5.570100           NaN
# 75%                NaN    NaN          NaN      6.768000           NaN
# max                NaN    NaN          NaN     29.591800           NaN
#
#         text_spt ref_normalized hyp_normalized           wer           cer  \
# count      79268          79254          79268  79268.000000  79268.000000
# unique     68267          68178          68200           NaN           NaN
# top     [musiqa]       [musiqa]       [musiqa]           NaN           NaN
# freq         125            280            274           NaN           NaN
# mean         NaN            NaN            NaN      0.022216      0.005449
# std          NaN            NaN            NaN      0.069452      0.035587
# min          NaN            NaN            NaN      0.000000      0.000000
# 25%          NaN            NaN            NaN      0.000000      0.000000
# 50%          NaN            NaN            NaN      0.000000      0.000000
# 75%          NaN            NaN            NaN      0.000000      0.000000
# max          NaN            NaN            NaN      2.500000      2.230800
#
#         ...  hyp_word_count                            speaker_id  \
# count   ...    79268.000000                                 62933
# unique  ...             NaN                                  4170
# top     ...             NaN  64f7ffe1-2c4e-459e-9155-5fc9a0bbe539
# freq    ...             NaN                                  1459
# mean    ...       11.532081                                   NaN
# std     ...       10.369921                                   NaN
# min     ...        1.000000                                   NaN
# 25%     ...        7.000000                                   NaN
# 50%     ...        8.000000                                   NaN
# 75%     ...       10.000000                                   NaN
# max     ...       97.000000                                   NaN
#
#                                               sentence_id      up_votes  \
# count                                                2502  62933.000000
# unique                                               2502           NaN
# top     2df183e98e1caf5e45b1d65b9c76b2d9d7e64e4f54e75d...           NaN
# freq                                                    1           NaN
# mean                                                  NaN      0.816011
# std                                                   NaN      1.816892
# min                                                   NaN      0.000000
# 25%                                                   NaN      0.000000
# 50%                                                   NaN      0.000000
# 75%                                                   NaN      0.000000
# max                                                   NaN     26.000000
#
#           down_votes    age           gender accent_region    word_count  \
# count   62933.000000  61203            61851         59818  63763.000000
# unique           NaN     16                3            17           NaN
# top              NaN  18-24  female_feminine        Jizzax           NaN
# freq             NaN  45144            34778          8326           NaN
# mean        0.010281    NaN              NaN           NaN      7.908285
# std         0.105191    NaN              NaN           NaN      2.281854
# min         0.000000    NaN              NaN           NaN      2.000000
# 25%         0.000000    NaN              NaN           NaN      7.000000
# 50%         0.000000    NaN              NaN           NaN      8.000000
# 75%         0.000000    NaN              NaN           NaN      9.000000
# max         4.000000    NaN              NaN           NaN     39.000000
#
#        reported_count
# count    60431.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.005610
# std          0.076872
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          2.000000
#
# [11 rows x 22 columns]

# %%
print_dataset_statistics(combined_case_sensitive_df)
# Out:
# At least 4,170 speakers involved
#
# Combined total duration: 161.00 hours (86.03% is training data)
# Reed speech training data duration: 78.74 hours (56.85%)
# Conversation speech training data duration: 59.77 hours (43.15%)
# Augmented duration: 27.16 hours
# Augmented portion in training data: 19.61%
#
# dataset        type
# common_voice   test           2.751890
#                validation     1.328719
# feruza_speech  train          3.217020
# it             test           0.737151
#                train          7.940193
#                validation     0.735187
# news           test           1.729239
#                train         51.826843
#                validation     1.106672
# uzbek_voice    test           7.160320
#                train         75.527433
#                validation     6.939970
# Name: duration, dtype: float64
#
# dataset        is_augmented
# common_voice   False            4.080609
# feruza_speech  True             3.217020
# it             False            1.472338
#                True             7.940193
# news           False           46.839936
#                True             7.822818
# uzbek_voice    False           81.446070
#                True             8.181653
# Name: duration, dtype: float64
#
# dataset        gender
# common_voice   female_feminine     0.324347
#                male_masculine      2.047106
#                NaN                 1.709156
# feruza_speech  NaN                 3.217020
# it             NaN                 9.412531
# news           NaN                54.662754
# uzbek_voice    female_feminine    51.979407
#                male_masculine     36.809486
#                not_specified       0.838830
# Name: duration, dtype: float64

# %%
from scripts.dataset_plotting import plot_distribution_graphs

plot_distribution_graphs(combined_case_sensitive_df)
